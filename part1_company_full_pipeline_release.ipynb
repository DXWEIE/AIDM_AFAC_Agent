# %% [markdown]
# 生成公司/个股研报应能够自动抽取三大会计报表与股权结构，输出主营业务、核心竞争力与行业地位；
# 支持财务比率计算与行业对比分析（如ROE分解、毛利率、现金流匹配度），结合同行企业进行横向竞争分析；
# 构建估值与预测模型，模拟关键变量变化对财务结果的影响（如原材料成本、汇率变动）；
# 结合公开数据与管理层信息，评估公司治理结构与发展战略，提出投资建议与风险提醒

# %% [markdown]
# TODO
# 写一些执行函数的代码，inject的参数是stock_type和stock_code，在获得这两个后，后面invoke需要inject
#
#
# langchain执行函数：https://python.langchain.com/docs/how_to/tool_results_pass_to_model/
#
#
# langchain的inject参数：https://python.langchain.com/docs/how_to/tool_runtime/
#
# 百度的任务规划后搜集信息和判断信息搜集是否ok的prompt：https://github.com/PaddlePaddle/ERNIE/blob/develop/cookbook/notebook/advanced_search_demo_en.ipynb

# %% [markdown]
# akshare文档：https://akshare.akfamily.xyz/data/stock/stock.html
# 比赛官网: https://tianchi.aliyun.com/competition/entrance/532354/information
# 比赛baseline ：https://www.datawhale.cn/learn/summary/174
# 前置需要：注册千帆和阿里云，申请api，只能调用开源模型的api，百度不能调用ai搜索的基于模型的可以base的非模型的搜索
# TODO——整理出funciton，比如画图等等，把下面的都包装成支持函数调用的
#
# langchain的文档： https://python.langchain.com/docs/how_to/
# langchain的function call的文档，定义-bind就可以了：https://python.langchain.com/docs/how_to/tool_calling/
# langchain的demo2：https://blog.csdn.net/qq_37734256/article/details/148511363

# %% [markdown]
# # 0. 题目

# %%
#input_stock_code = '公司：4Paradigm（06682.HK）' # 输入的信息
company_name = '4Paradigm'  # 公司名称
company_code = '06682.HK'  # 公司代码
input_stock_code = f"{company_name}（{company_code}）" 

task1 = f"""请帮我生成公司/个股研报，目标公司和股票信息是 {input_stock_code}。
要求能够自动抽取三大会计报表与股权结构，输出主营业务、核心竞争力与行业地位；支持财务比率计算与行业对比分析（如ROE分解、毛利率、现金流匹配度），结合同行企业进行横向竞争分析；构建估值与预测模型，模拟关键变量变化对财务结果的影响（如原材料成本、汇率变动）；结合公开数据与管理层信息，评估公司治理结构与发展战略，提出投资建议与风险提醒。"""

# %%
from langchain_community.chat_models.tongyi import ChatTongyi
from langchain_openai import ChatOpenAI
api_key = 'sk-xxxx'  # 我的


deepseek_r1 = ChatOpenAI(model="deepseek-r1", temperature=0, api_key=api_key, 
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1")


deepseek_v3 = ChatOpenAI(model="deepseek-v3", temperature=0, api_key=api_key, 
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1")

kimi_model = ChatOpenAI(model="Moonshot-Kimi-K2-Instruct", temperature=0, api_key=api_key, 
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1")


base_model = ChatTongyi(
    model="qwen3-235b-a22b",
    api_key=api_key,temperature=0
)
tool_agent = ChatTongyi(
    model="qwen3-235b-a22b",
    api_key=api_key,temperature=0
)

# %%
import akshare as ak
import pandas as pd
from get_capital_structure import get_capital_structure_cn_ths, get_capital_structure_hk_ths
from get_cn_control import get_cn_control
from get_company_field_compare import get_cn_company_field_compare, get_hk_company_field_compare
from get_company_finance_summary import get_company_finance_summary_cn,get_company_finance_summary_hk
from get_company_intro import get_company_profile_ths_cn, get_company_profile_ths_hk, get_cn_company_profile_ak, get_hk_company_profile_ak
from get_financial_data_annual import download_cn_financial_data, download_hk_financial_data
from get_rating_info import get_hk_rating_info, get_cn_rating_info
from get_stock_info import get_cn_stock_info, get_hk_stock_info
from get_worth_predict import get_cn_worth_predict, get_hk_worth_predict
from datetime import datetime, timedelta
import time
import requests
from langchain_openai import ChatOpenAI
from langchain.agents import initialize_agent, Tool
from typing import Dict, Any
from typing_extensions import Annotated, TypedDict
import json
from langchain_core.messages import AIMessage, HumanMessage, ToolMessage,SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from typing import Dict, Optional, Literal
from pydantic import BaseModel, Field
from langchain.tools import BaseTool
import ast
import pickle

from typing import List

from langchain_core.tools import InjectedToolArg, tool
from typing_extensions import Annotated
import time
from time import sleep
# 支持matplotlib输出中文
import matplotlib.pyplot as plt
import chineseize_matplotlib
plt.rcParams['axes.unicode_minus'] = False # 解决负号'-'显示为方块的问题

# %% [markdown]
# # 1. 数据采集函数定义

# %%
######################## 0. 公司和股票信息
def extract_company_basic_info(stock_type,stock_code):
    """
    输入股票类型和股票代码，提取公司的基本信息
    Args:
        stock_type (str): 股票类型，'A股' 或 '港股'
        stock_code (str): 股票代码，A股为6位数字，港股为4位数字
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_value (Dict[str, str]): 公司基本信息数据值，包括公司名称、英文名称、主营业务、所属行业和公司简介
            data_type (str): 数据类型
            data_desc (str): 数据内容描述，说明返回的数据包含哪些信息

    """
    if stock_type == '港股':
        hk_code = 'HK' + stock_code
        company_info = get_company_profile_ths_hk(hk_code)
    else:
        a_code = stock_code
        company_info = get_company_profile_ths_cn(a_code)

    return {
        'data_value': {
            "公司名称": company_info['公司名称'],
            "英文名称": company_info['英文名称'],
            "主营业务": company_info['主营业务'],
            "所属行业": company_info['所属行业'],
            "公司简介": company_info['公司简介']
        },
        'data_type': 'dict',
        'data_desc': '公司基本信息，包括公司名称、英文名称、主营业务、所属行业和公司简介'
    }

# 提取公司基本信息
# company_basic_info = extract_company_basic_info(stock_type, stock_code)

## 获取最近的几个月，月度的股票数据
def get_date_range_months(months_back=6):
    end_date = datetime.today().replace(day=1)  # 当月1号
    start_date = end_date - timedelta(days=30*months_back)
    start_date = start_date.replace(day=1)  # 第一天
    return {
        "start_date": start_date.strftime("%Y%m%d"),
        "end_date": end_date.strftime("%Y%m%d")
    }

# start_date = get_date_range_months()["start_date"]
# end_date = get_date_range_months()["end_date"]

# if stock_type=='港股':
#     hk_code = 'HK'+stock_code
#     # 获取近6个月的股票信息，获取近6个月的1号的信息
#     stock_info = get_hk_stock_info(hk_code,period="monthly", start_date=start_date, end_date=end_date) # 参数可以控制日期
#     # 单位是港元
#     # ['日期', '开盘', '收盘', '最高', '最低', '成交量', '成交额', '振幅', '涨跌幅', '涨跌额', '换手率']
# else:
#     a_code = stock_code
#     stock_info = get_cn_stock_info(a_code,period="monthly", start_date=start_date, end_date=end_date)
#     # 单位是人民币
#     # 日期	开盘	收盘	最高	最低	成交量	成交额	振幅	涨跌幅	涨跌额	换手率


def extract_stock_info(stock_type, stock_code,months_back=6):
    """
    提取公司股票的近期基本价格和成交信息，默认提取最近6个月的月度数据；
    返回值是一个字典，包含日期、开盘、收盘、最高、最低、成交量、成交额、振幅、涨跌幅、涨跌额和换手率等信息。
    返回结果的价格，对于港股单位是港元，对于A股单位是人民币。
    Args:
        stock_type (str): 股票类型，'A股' 或 '港股'
        stock_code (str): 股票代码，A股为6位数字，港股为4位数字
        months_back (int): 回溯的月数，默认为6个月
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_name (Dict[str, list]): 存放数据值，包含日期、开盘、收盘、最高、最低、成交量、成交额、振幅、涨跌幅、涨跌额和换手率
            data_type (Dict[str, str]): 数据类型
            data_desc (Dict[str, str]): 包含上述信息的内容描述
    """
    start_date = get_date_range_months(months_back)["start_date"]
    end_date = get_date_range_months(months_back)["end_date"]
    if stock_type == '港股':
        hk_code = 'HK' + stock_code
        stock_info = get_hk_stock_info(hk_code, period="monthly", start_date=start_date, end_date=end_date)
    else:
        a_code = stock_code
        stock_info = get_cn_stock_info(a_code, period="monthly", start_date=start_date, end_date=end_date)

    return {
        'data_value': {
            "股票近期价格和交易信息": stock_info
    },
        'data_type': 'dict_dataframe',
        'data_desc': '包含股票的日期、开盘价、收盘价、最高价、最低价、成交量、成交额、振幅、涨跌幅、涨跌额和换手率等信息，通过key值访问list数据'
    }

# 提取股票信息
# stock_info = extract_stock_info(stock_type, stock_code)


################## 1. 获取股本结构

def extract_capital_structure(stock_type, stock_code):
    """
    提取股本结构信息
    Args:
        stock_type (str): 股票类型，'A股' 或 '港股'
        stock_code (str): 股票代码，A股为6位数字，港股为4位数字
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_value (Dict[str, list]): 股本结构数据值，港股的包括总股本、港股总股本、优先股和变动日期；A股包括总股本、A股总股本、流通A股、限售A股和变动原因
            data_type (str): 数据类型
            data_desc (str): 数据内容描述，说明返回的数据包含哪些信息
    """
    if stock_type == '港股':
        hk_code = 'HK' + stock_code
        captial_structure = get_capital_structure_hk_ths(hk_code)
        return {
            'data_value': {
                "港股股本": captial_structure,
            },
            'data_type': 'dict_dataframe',
            'data_desc': '对应港股的股本结构信息，包括总股本、港股总股本、优先股和变动日期'
        }
    else:
        a_code = stock_code
        cn_captial_structure = get_capital_structure_cn_ths(a_code)
        # return {
        #     "总股本(股)": cn_captial_structure['总股本(股)'],
        #     "A股总股本(股)": cn_captial_structure['A股总股本(股)'],
        #     "流通A股(股)": cn_captial_structure['流通A股(股)'],
        #     "限售A股(股)": cn_captial_structure['限售A股(股)'],
        #     "变动原因": cn_captial_structure['变动原因']
        # }
        return {
            'data_value': {
                "A股股本": cn_captial_structure
            },
            'data_type': 'dict_dataframe',
            'data_desc': '对应A股的股本结构信息，包括总股本、A股总股本、流通A股、限售A股和变动原因'
        }

# 提取股本结构信息
# capital_structure = extract_capital_structure(stock_type, stock_code)


# ##资产负债表：反映企业在特定日期的财务状况，包括资产、负债和所有者权益。
# ##利润表：展示企业在一定会计期间的经营成果，反映企业的收入、费用和利润。
# ##现金流量表：记录企业在特定期间内的现金流入和流出，反映企业的现金流动情况。


# TODO--这个是个大表，看一下到底需要哪些列的信息
def extract_financial_statements(stock_type, stock_code):
    """
    提取年度三大会计报表：资产负债表、利润表和现金流量表
    返回值是一个字典，包含三个DataFrame，分别对应资产负债表、利润表和现金流量表。
    Args:
        stock_type (str): 股票类型，'A股' 或 '港股'
        stock_code (str): 股票代码，A股为6位数字，港股为4位数字
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_value (Dict[str, pd.DataFrame]): 包含三个DataFrame的字典，分别是资产负债表、利润表和现金流量表
            data_type (str): 数据类型
            data_desc (str): 数据内容描述，说明返回的数据包含哪些信息
    """
    if stock_type == '港股':
        hk_code = 'HK' + stock_code
        hk_code = hk_code.upper()
        hk_code = ''.join(filter(str.isdigit, hk_code))  # 只保留数字
        if len(hk_code) > 4:
            hk_code = hk_code[-4:]
        hk_code = '0' + hk_code  # 确保是5位数字
        stock_financial_bi_df = ak.stock_financial_hk_report_em(stock=hk_code, symbol="资产负债表", indicator="年度")
        stock_benefit_bi_df = ak.stock_financial_hk_report_em(stock=hk_code, symbol="利润表", indicator="年度")
        stock_cash_bi_df = ak.stock_financial_hk_report_em(stock=hk_code, symbol="现金流量表", indicator="年度")
    else:
        a_code = stock_code
        stock_financial_bi_df = ak.stock_financial_debt_ths(symbol=a_code, indicator="按年度")
        stock_benefit_bi_df = ak.stock_financial_benefit_ths(symbol=a_code, indicator="按年度")
        stock_cash_bi_df = ak.stock_financial_cash_ths(symbol=a_code, indicator="按年度")

    return {
        'data_value': {
            "资产负债表": stock_financial_bi_df,
            "利润表": stock_benefit_bi_df,
            "现金流量表": stock_cash_bi_df
        },
        'data_type': 'dict_dataframe',
        'data_desc': '包含对应股票代码的会计报表'
    }

# 提取年度三大会计报表
# financial_statements = extract_financial_statements(stock_type, stock_code)



########### 4. 港股ROE数据分析


def extract_hk_financial_analysis(stock_type, stock_code):
    """
    提取港股的财务指标分析数据
    Args:
        stock_type (str): 股票类型，'港股'
        stock_code (str): 港股股票代码，4位数字
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_value (Dict[str, pd.DataFrame]): 港股财务分析指标数据，包含ROE等指标
            data_type (str): 数据类型
            data_desc (str): 数据内容描述，说明返回的数据包含哪些财务指标分析数据
    """
    if stock_type == '港股':
        hk_code = 'HK' + stock_code
        hk_code = hk_code.upper()
        hk_code = ''.join(filter(str.isdigit, hk_code))  # 只保留数字
        if len(hk_code) > 4:
            hk_code = hk_code[-4:]
        hk_code = '0' + hk_code  # 确保是5位数字
        stock_financial_analysis_indicator_em_df = ak.stock_financial_hk_analysis_indicator_em(symbol=hk_code, indicator="年度")
        return {
            'data_value': {'港股财务分析指标数据':stock_financial_analysis_indicator_em_df},
            'data_type': 'dict_dataframe',
            'data_desc': '港股的财务指标分析数据，包括ROE等指标'
        }
    else:
        return None
    
# 提取港股的财务指标分析数据
# hk_financial_analysis = extract_hk_financial_analysis(stock_type, stock_code)


############# 5. 获取财务摘要信息总结

def extract_financial_summary(stock_type, stock_code):
    """
    提取公司财务摘要信息
    Args:
        stock_type (str): 股票类型，'A股' 或 '港股'
        stock_code (str): 股票代码，A股为6位数字，港股为4位数字
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_value (Dict[str, str]): 公司财务摘要信息
            data_type (str): 数据类型
            data_desc (str): 数据内容描述，说明返回的数据包含哪些信息
    """
    if stock_type == '港股':
        hk_code = 'HK' + stock_code
        official_finance_summary = get_company_finance_summary_hk(hk_code)
    else:
        a_code = stock_code
        official_finance_summary = get_company_finance_summary_cn(a_code)

    return {
        'data_value': {
            "财务摘要": official_finance_summary
        },
        'data_type': 'dict',
        'data_desc': '公司财务信息的摘要分析信息，包括业绩回顾、展望和竞争力分析等内容'
    }
# 提取财务摘要信息
# financial_summary = extract_financial_summary(stock_type, stock_code)


################### 6. 获取行业对比信息

def extract_field_compare(stock_type, stock_code):
    """
    提取行业对比分析数据
    Args:
        stock_type (str): 股票类型
        stock_code (str): 股票代码
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_value (Dict[str, dict]): 行业对比分析数据，包含目标公司和同行业其他公司的对比数据
            data_type (str): 数据类型
            data_desc (str): 数据内容描述，说明返回的数据包含哪些行业对比分析数据
    """
    if stock_type == '港股':
        hk_code = 'HK' + stock_code
        field_compare = get_hk_company_field_compare(hk_code)  # 港股包括
    else:
        a_code = stock_code
        field_compare = get_cn_company_field_compare(a_code)

    issue_list = []
    title_list = []
    ps_list = []
    dataframe_list = []
    for item in field_compare:
        issue_list.append(item['issue'])
        title_list.append(item['title'])
        ps_list.append(item['ps'])
        dataframe_list.append(item['table'])
    return {
        'data_value':{
            "issue": issue_list,
            "title": title_list,
            "ps": ps_list,
            "table": dataframe_list
        },
        'data_type': 'dict_special_list',
        'data_desc': '行业对比分析数据，包含目标公司和同行业其他公司的对比数据，是一个list，包括issue，title，ps和数据table，table是原始数据dataframe'
    }


# 提取行业对比分析数据
# field_compare_data = extract_field_compare(stock_type, stock_code)

################# 7. 综合分析，展望未来
def extract_rating_info(stock_type: Annotated[str, InjectedToolArg], stock_code: Annotated[str, InjectedToolArg]):
    """
    提取评级信息
    Args:
        stock_type (str): 股票类型，'A股' 或 '港股'
        stock_code (str): 股票代码，A股为6位数字，港股为4位数字
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_value (Dict[str, Any]): 评级信息，包括评级机构的评级和投资建议
            data_type (str): 数据类型
            data_desc (str): 数据内容描述，说明返回的数据包含哪些评级信息
    """
    if stock_type == '港股':
        hk_code = 'HK' + stock_code
        rating_info = get_hk_rating_info(hk_code)
    else:
        a_code = stock_code
        rating_info = ak.stock_profit_forecast_ths(symbol=a_code, indicator="业绩预测详表-机构")

    return {
        'data_value': {
            "评级信息": rating_info
        },
        'data_type': 'dict_dataframe',
        'data_desc': '评级信息，包括评级机构的评级和投资建议，主要关注机构和研究员给出的数据指标是否建议买入'
    }

# 提取评级信息
# rating_info = extract_rating_info(stock_type, stock_code)


################## 8.未来和价值预测信息



def extract_worth_predict(stock_type: Annotated[str, InjectedToolArg], stock_code: Annotated[str, InjectedToolArg]):
    """
    提取股票收益和价值预测信息
    Args:
        stock_type (str): 股票类型，'A股' 或 '港股'
        stock_code (str): 股票代码，A股为6位数字，港股为4位数字
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_value (Dict[str, pd.DataFrame]): 股票收益和价值预测信息，包括盈利预测概览和详细指标预测的数据值
            data_type (str): 数据类型
            data_desc (str): 数据内容描述，说明返回的数据包含哪些股票收益和价值预测信息
    """
    if stock_type == '港股':
        hk_code = 'HK' + stock_code
        hk_code = hk_code.upper()
        hk_code = ''.join(filter(str.isdigit, hk_code))  # 只保留数字
        if len(hk_code) > 4:
            hk_code = hk_code[-4:]
        hk_code = '0' + hk_code  # 确保是5位数字
        predict_info = ak.stock_hk_profit_forecast_et(symbol=hk_code, indicator="盈利预测概览")
    else:
        a_code = stock_code
        predict_info = ak.stock_profit_forecast_ths(symbol=a_code, indicator="业绩预测详表-详细指标预测")

    return {
        'data_value': {
            "预测信息": predict_info
        },
        'data_type': 'dict_dataframe',
        'data_desc': '股票收益和价值预测信息，包括盈利预测概览和详细指标预测的数据值'
    }

# 提取股票收益和价值预测信息
# worth_predict = extract_worth_predict(stock_type, stock_code)

# %% [markdown]
# # 2. 数据获取和下载

# %%
# 信息获取后，数据存储到dict里面
collected_data_value = {}
collected_data_type = {}
collected_data_desc = {}

# %%
def save_extracted_info(data_value,
                        data_type,
                        data_desc):
    global collected_data_value, collected_data_type, collected_data_desc
    if data_type=='dict': # 普通的dict直接放进去就可以了
        collected_data_value.update(data_value)
        # 注意提取出data_value里面的key作为后面的数据类型和描述的key
        for key in data_value.keys():
            collected_data_type[key] = 'str'
            collected_data_desc[key] = str(key)
    elif data_type=='dict_dataframe':
        collected_data_value.update(data_value)
        # 注意提取出data_value里面的key作为后面的数据类型和描述的key
        for key in data_value.keys():
            collected_data_type[key] = 'dataframe'
            collected_data_desc[key] = data_desc
    elif data_type=='dict_special_list': # 最复杂的一种，这个的data_value是一个list
        for i in range(len(data_value['issue'])):
            issue = data_value['issue'][i]
            title = data_value['title'][i]
            ps = data_value['ps'][i]
            dataframe = data_value['table'][i]
            description = f"{issue} - {title} - ({ps})"
            if '行业分类' in title:
                key = str(issue) + '行业财务数据'
            else:
                if '价值' in title or '表现' in title:
                    key = str(issue) + '行业价值表现数据'
                else:
                    key = str(issue) + '行业财务经营数据'
            collected_data_value[key] = dataframe
            collected_data_type[key] = 'dataframe'
            collected_data_desc[key] = description


import pickle

def save_collected_data_to_local():
    with open('collected_data_value.pkl', 'wb') as f:
        pickle.dump(collected_data_value, f)
    with open('collected_data_type.pkl', 'wb') as f:
        pickle.dump(collected_data_type, f)
    with open('collected_data_desc.pkl', 'wb') as f:
        pickle.dump(collected_data_desc, f)

    print("数据已成功保存到本地。")

def load_collected_data_from_local():
    global collected_data_value, collected_data_type, collected_data_desc
    try:
        with open('collected_data_value.pkl', 'rb') as f:
            collected_data_value = pickle.load(f)
        with open('collected_data_type.pkl', 'rb') as f:
            collected_data_type = pickle.load(f)
        with open('collected_data_desc.pkl', 'rb') as f:
            collected_data_desc = pickle.load(f)
        print("数据已从本地加载。")
    except FileNotFoundError:
        print("未找到本地数据文件，请先运行保存操作。")

# %%
def judge_stock_type(input_stock_code: str):
    """
    调用该函数，从混合着股票代码和公司信息的输入判断股票是A股的还是港股的，并提取出准确的股票代码。
    Args:
        input_stock_code (str): 输入的股票代码和公司信息
    Returns:
        Dict[str, Any]: 包含以下键的字典：
            data_value (Dict[str, str]): 包含股票类型（A股或港股）和对应的股票代码
            data_type (str): 数据类型
            data_desc (str): 数据描述
    例如：
    """
    prompt = """你是一个股票研究专家，请判断这个股票代码是A股还是港股，并返回股票代码。对于A股，返回6位纯数字的股票代码；对于港股，返回4位纯数字的股票代码。
    股票代码和公司信息是：{stock_code}
    请只返回股票代码，不要包含其他任何信息。你输出的股票代码为："""
    response = base_model.invoke(prompt.format(stock_code=input_stock_code),enable_thinking=False)
    stock_code = response.content.strip()
    if len(stock_code) == 6:
        stock_type = 'A股'
    else:
        stock_type = '港股'
    return stock_type, stock_code
stock_type, stock_code = judge_stock_type(input_stock_code)

# %%
# 2. 提取这个公司的基本信息
company_basic_info = extract_company_basic_info(stock_type, stock_code)
save_extracted_info(
    data_value=company_basic_info['data_value'],
    data_type=company_basic_info['data_type'],
    data_desc=company_basic_info['data_desc']
)

# 3. 提取近期股票基本数据
stock_info = extract_stock_info(stock_type, stock_code)

save_extracted_info(
    data_value=stock_info['data_value'],
    data_type=stock_info['data_type'],
    data_desc=stock_info['data_desc']
)

# 4. 提取三大财务报表数据
financial_statements = extract_financial_statements(stock_type, stock_code)

save_extracted_info(
    data_value=financial_statements['data_value'],
    data_type=financial_statements['data_type'],
    data_desc=financial_statements['data_desc']
)

# 5. 如果是港股，提取港股财务分析指标数据包括ROE等
hk_financial_analysis = extract_hk_financial_analysis(stock_type, stock_code)
# 保存到本地

save_extracted_info(
    data_value=hk_financial_analysis['data_value'],
    data_type=hk_financial_analysis['data_type'],
    data_desc=hk_financial_analysis['data_desc']
)
save_collected_data_to_local()

# 6. 提取公司财务摘要信息
financial_summary = extract_financial_summary(stock_type, stock_code)
save_extracted_info(
    data_value=financial_summary['data_value'],
    data_type=financial_summary['data_type'],
    data_desc=financial_summary['data_desc']
)


# 7. 提取行业对比分析数据
field_compare_data = extract_field_compare(stock_type, stock_code)
save_extracted_info(
    data_value=field_compare_data['data_value'],
    data_type=field_compare_data['data_type'],
    data_desc=field_compare_data['data_desc']
)
save_collected_data_to_local()


# 8. 提取股票评级信息
rating_info = extract_rating_info(stock_type, stock_code)
save_extracted_info(
    data_value=rating_info['data_value'],
    data_type=rating_info['data_type'],
    data_desc=rating_info['data_desc']
)



# 9. 提取股票收益和价值预测信息
worth_predict_info = extract_worth_predict(stock_type, stock_code)
save_extracted_info(
    data_value=worth_predict_info['data_value'],
    data_type=worth_predict_info['data_type'],
    data_desc=worth_predict_info['data_desc']
)
save_collected_data_to_local()
# Out:
# 数据已成功保存到本地。
# 数据已成功保存到本地。
# 数据已成功保存到本地。

# %% [markdown]
# # 3.数据加载

# %%
import pandas as pd
import pickle
def load_collected_data_from_local():
    global collected_data_value, collected_data_type, collected_data_desc
    try:
        with open('collected_data_value.pkl', 'rb') as f:
            collected_data_value = pickle.load(f)
        with open('collected_data_type.pkl', 'rb') as f:
            collected_data_type = pickle.load(f)
        with open('collected_data_desc.pkl', 'rb') as f:
            collected_data_desc = pickle.load(f)
        print("数据已从本地加载。")
    except FileNotFoundError:
        print("未找到本地数据文件，请先运行保存操作。")
        
# 信息获取后，数据存储到dict里面
collected_data_value = {}
collected_data_type = {}
collected_data_desc = {}
# 数据加载完毕
load_collected_data_from_local()
# 数据在collected_data_value, collected_data_type, collected_data_desc 

df1 = collected_data_value['资产负债表']
df2 = df1.pivot(index='REPORT_DATE', columns='STD_ITEM_NAME', values='AMOUNT')

# 重置索引，让 REPORT_DATE 变回列（可选）
df2.reset_index(inplace=True)

# 去掉列索引的名字
df2.columns.name = None
# 转换为yyyy-mm-dd格式
df2['REPORT_DATE'] = pd.to_datetime(df2['REPORT_DATE']).dt.strftime('%Y-%m-%d')
collected_data_value['资产负债表'] = df2

df1 = collected_data_value['利润表']
df2 = df1.pivot(index='REPORT_DATE', columns='STD_ITEM_NAME', values='AMOUNT')

# 重置索引，让 REPORT_DATE 变回列（可选）
df2.reset_index(inplace=True)

# 去掉列索引的名字
df2.columns.name = None
# 转换为yyyy-mm-dd格式
df2['REPORT_DATE'] = pd.to_datetime(df2['REPORT_DATE']).dt.strftime('%Y-%m-%d')
collected_data_value['利润表'] = df2

df1 = collected_data_value['现金流量表']
df2 = df1.pivot(index='REPORT_DATE', columns='STD_ITEM_NAME', values='AMOUNT')

# 重置索引，让 REPORT_DATE 变回列（可选）
df2.reset_index(inplace=True)

# 去掉列索引的名字
df2.columns.name = None
# 转换为yyyy-mm-dd格式
df2['REPORT_DATE'] = pd.to_datetime(df2['REPORT_DATE']).dt.strftime('%Y-%m-%d')
collected_data_value['现金流量表'] = df2

df1 = collected_data_value['港股财务分析指标数据']
df1['REPORT_DATE'] = pd.to_datetime(df1['REPORT_DATE']).dt.strftime('%Y-%m-%d')
df2 = df1.loc[:,['REPORT_DATE','ROE_AVG','ROA', 'PER_NETCASH_OPERATE','PER_OI', 'BPS',
       'BASIC_EPS', 'DILUTED_EPS', 'OPERATE_INCOME', 'OPERATE_INCOME_YOY',
       'GROSS_PROFIT', 'GROSS_PROFIT_YOY', 'HOLDER_PROFIT',
       'HOLDER_PROFIT_YOY', 'GROSS_PROFIT_RATIO', 'EPS_TTM',
       'OPERATE_INCOME_QOQ', 'NET_PROFIT_RATIO', 'GROSS_PROFIT_QOQ',
        'HOLDER_PROFIT_QOQ', 'ROE_YEARLY', 'ROIC_YEARLY', 'TAX_EBT',
       'OCF_SALES', 'DEBT_ASSET_RATIO', 'CURRENT_RATIO', 'CURRENTDEBT_DEBT','CURRENCY']]
collected_data_value['港股财务分析指标数据'] = df2

collected_data_size = {}
# 只需要对dataframe类型的数据进行大小计算，其他的认为很小就行，dataframe的返回行列，文本的形式
def gen_collected_data_size():
    global collected_data_value, collected_data_type, collected_data_size
    for key, value in collected_data_value.items():
        if collected_data_type[key] == 'dataframe':
            # 获取DataFrame的行数和列数
            size_info = value.shape
            collected_data_size[key] = "行数为 {}, 列数为 {}".format(size_info[0], size_info[1])
        else:
            # 其他类型认为是小数据
            collected_data_size[key] = {"小的文本数据"}

gen_collected_data_size()
# Out:
# 数据已从本地加载。

# %% [markdown]
# # 4. 任务拆分

# %%
# RAG的思路
collected_data_value.keys()

# 注意数据里面的对应股票代码，指的是要完成的金融报告的指定公司的股票代码，除了行业价值表现数据和财务经营数据外，其他的数据里面只有要完成的金融报告的指定公司的信息。
collected_data_desc['财务摘要'] = '包含对应股票代码的财务信息的数据摘要分析'
collected_data_desc['股票近期价格和交易信息'] = '包含对应股票的日期、开盘价、收盘价、最高价、最低价、成交量、成交额、振幅、涨跌幅、涨跌额和换手率等信息'



all_data_chunks = []
def construct_collected_data_chunks(collected_data_value,collected_data_desc):
    """
    构造数据块字符串，包含collected_data_value和collected_data_desc的内容
    :param collected_data_value: 收集到的数据字典
    :param collected_data_desc: 收集到的数据描述字典
    :return: 数据块字符串
    """
    global all_data_chunks
    data_chunks_disc_list = []
    idx = 1
    for key, value in collected_data_value.items():
        desc = collected_data_desc.get(key, "无描述")
        discription = f"数据块{idx}: {key} - {desc}\n"
        data_chunks_disc_list.append(discription)
        # 如果是DataFrame类型的数据，转换为字符串
        if isinstance(value, pd.DataFrame):
            table_intro = f'{key} - {desc}'
            table_str = value.to_csv(sep='|', index=False, header=True)
            result_str = f"{table_intro}\n{table_str}"
        else:
            # 如果是其他类型的数据，直接转换为字符串
            result_str = f"{key} - {desc}\n{str(value)}"
        all_data_chunks.append(result_str)  # 添加数据块内容
        idx += 1
    return "\n".join(data_chunks_disc_list)

data_chunks_disc = construct_collected_data_chunks(collected_data_value, collected_data_desc)

# 任务拆解，把研究任务拆解成多个子任务，每个子任务可以独立完成，按照顺序进行标号，不超过10个子任务

sub_task_plan_template = """
你是一个专业的金融研究员，需要撰写一篇关于 {stock_info} 的金融研究报告。当前的研究任务如下：

任务说明：
------------
{query}
------------

请你根据这个研究任务，按照逻辑顺序拆解为多个子任务。每个子任务应具备以下特征：
- 可以独立完成
- 按照写作或研究的先后顺序排列
- 数量不超过 10 个子任务

输出格式要求如下：
- 使用如下格式：
  #1# 子任务说明
  #2# 子任务说明
  ...
- 不使用任何 Markdown 格式
- 不添加任何解释性内容

请开始输出子任务计划。
"""

sub_task_plan_prompt = sub_task_plan_template.format(
    stock_info=input_stock_code,  # 输入的股票代码
    query=task1  # 当前的研究任务
)

sub_task_response = deepseek_v3.invoke(sub_task_plan_prompt)


import re
def generate_subtasks(llm_response):
    # 提取子任务
    subtasks = re.findall(r'#(\d+)#\s*(.+)', llm_response.strip())
    # 按顺序排序并去重
    subtasks = sorted(subtasks, key=lambda x: int(x[0]))
    unique_tasks = {}
    for idx, task in subtasks:
        if task not in unique_tasks:
            unique_tasks[task] = None
    # 返回任务列表
    return list(unique_tasks.keys())

task_list = generate_subtasks(sub_task_response.content)


# 输出结果
# ['收集4Paradigm（06682.HK）的基本信息，包括公司简介、上市时间、股票代码、交易所等基础资料  ',
#  '提取并整理4Paradigm的三大会计报表（资产负债表、利润表、现金流量表）数据  ',
#  '分析公司主营业务、核心竞争力与行业地位，包括市场份额、技术优势、客户群体等  ',
#  '计算关键财务比率（如ROE、毛利率、现金流匹配度等），并与行业同行进行对比分析  ',
#  '选取可比公司进行横向竞争分析，包括财务表现、市场定位、技术能力等  ',
#  '构建估值模型（如DCF、PE等），并对关键变量（如原材料成本、汇率变动）进行敏感性分析  ',
#  '评估公司治理结构与管理层信息，包括董事会构成、管理层背景、股权结构等  ',
#  '分析公司发展战略与未来规划，包括市场扩张、研发投入、合作项目等  ',
#  '提出投资建议，包括目标价、投资评级（买入、持有、卖出等）及依据  ',
#  '总结潜在风险因素，包括市场风险、经营风险、政策风险等，并给出风险提示']

# %% [markdown]
# ## 4.1 RAG——获取相关数据块，回答子问题

# %%
# 获取最相关的数据chunk块
find_most_relavent_chunks_template = """
    你是一个专业的金融研究员，需要对关于 {stock_info} 的问题给出非常专业精准的回答，因此你需要先从候选的数据池中选择出最相关的数据块以提供参考信息。
    该问题为：
    -----
    {task}
    -----

    为了回答该问题，你需要从以下数据池中选择最相关的数据块，获取信息作为参考：
    -----
    {data_chunks}
    -----

    请你筛选出回答该问题最有可能用到的数据块编号，最多选择6个数据块，最少选择1个数据块，每个数据块的编号之间用逗号分隔，直接输出编号，不要添加任何其他内容，例如 0,1
    不要解释、分析或者输出任何其他内容，只需要输出数据块标号，你判断需要使用的数据块标号是：
"""

# %%
# 用于生成报告正文内容的模板
subtask_solution_prompt_template = """
你是一个专业的金融研究员，正在撰写关于 {stock_info} 的公司研究报告。

当前章节需要涵盖的内容是：
-----
{task}
-----

你需要参考以下数据和信息：
-----
{used_data_chunk}
-----

请根据以上信息，撰写该章节的正式报告内容。要求如下：

1. 表述专业、逻辑清晰、内容翔实，适合用于正式研究报告；
2. 若涉及数据，应保证数据和参考信息里面一致，不能编造；
3. 若涉及表格，应使用Markdown格式输出表格，表格内容要清晰、易读，可以只呈现关键数据，例如按照年份进行采样或者汇总输出，但是表格内容要完整不能出现省略号；
4. 若涉及分析，应给出结论性判断（如趋势、对比、风险、机会等）；
5. 不要写“我将如何分析”，而是直接输出分析结论；
6. 不要写“步骤一、步骤二”；
7. 使用中文，语句通顺，格式规范。

请直接以正式报告内容的形式输出该章节内容。
"""

# %% [markdown]
# ## 4.2 子问题回答

# %%
# info_get_agent的输出信息记录，实时记录到文件中保存
info_get_agent_output_log = "info_get_agent_output.log"

# markdown_writer_agent的输出信息记录，实时记录到文件中保存
markdown_writer_agent_output_log = "markdown_writer_agent_output.log"

# 金融研究员agent获取信息的history记录
writer_agent_info_get_history = "writer_agent_info_get_history.log"

# 写作的输出除了写到markdown中，也实时写入一个文件中保存
markdown_writer_output_log = "markdown_writer_output.log"
current_data_write_text_log = 'current_data_write_text_log.log'

# 整体的trace的log
trace_log = "trace.log"
print_log = "print.log"

def write_print_to_log(text,path='print.log'):
    """
    将文本写入日志文件
    :param text: 要写入的文本
    :param path: 日志文件路径
    """
    with open(path, 'a', encoding='utf-8') as f:
        f.write(text + '\n')
        print(text)  # 同时输出到控制台

# %%
task_solution_list = []
for i in range(len(task_list)): # 依次完成任务
    task = task_list[i]  # 当前任务
    write_print_to_log(f"\n\n--------------------开始处理任务 {i+1}: {task} --------------------\n")
    retry = 0
    finish_flag = 0
    while retry<3 and finish_flag<=0:
        # 搜集和任务相关的信息，可以取出最相关的6个chunk
        find_most_relavent_chunks_prompt = find_most_relavent_chunks_template.format(
            stock_info=input_stock_code,  # 输入的股票代码
            task=task,  # 当前的任务
            data_chunks=data_chunks_disc  # 数据块描述字符串
        )
        find_chunk_response = base_model.invoke(find_most_relavent_chunks_prompt,enable_thinking=False)
        sleep(1)
        most_relevant_chunks = find_chunk_response.content.strip()  # 最相关的数据块编号
        # 解析chunk编号
        most_relevant_chunks_list = most_relevant_chunks.split(',')  # 分割成列表
        # 检查数据格式是否准确
        most_relevant_chunks_list = [chunk.strip() for chunk in most_relevant_chunks_list if chunk.strip().isdigit()]
        if len(most_relevant_chunks_list) == 0:
            write_print_to_log(f"A没有找到相关的数据块，任务 {i+1} 无法完成")
            most_relevant_chunks_list = [0]
        write_print_to_log(f"最相关的数据块编号: {most_relevant_chunks_list}")
        # trace_log输出
        with open(trace_log, 'a', encoding='utf-8') as f:
            f.write(f"Most relevant chunks: {most_relevant_chunks}\n")
        finish_flag = 1 # 有数据了
        # 构建数据块字符串
        used_data_chunk = []
        for k in range(len(most_relevant_chunks_list)):
            chunk_index = int(most_relevant_chunks_list[k])
            if chunk_index < len(all_data_chunks):
                used_data_chunk.append(all_data_chunks[chunk_index])
        
        used_data_chunk_str = '\n\n'.join(used_data_chunk)

        # 生成任务解决方案
        subtask_solution_prompt = subtask_solution_prompt_template.format(
            stock_info=input_stock_code,  # 输入的股票代码
            task=task,  # 当前的任务
            used_data_chunk=used_data_chunk_str  # 使用的数据块字符串
        )

        subtask_solution_response = deepseek_r1.invoke(subtask_solution_prompt)
        sleep(1)
        subtask_solution = subtask_solution_response.content
        task_solution_list.append(subtask_solution)  # 存储任务解决方案
        # trace_log输出
        with open(trace_log, 'a', encoding='utf-8') as f:
            f.write(f"Subtask solution: {subtask_solution}\n")
        write_print_to_log('\n\n--------------------子任务解决方案--------------------\n')
        write_print_to_log(f"Subtask solution:\n {subtask_solution}")

# 数据保存，保存任务解决方案到pickle
import pickle
with open('task1_solution_list.pkl', 'wb') as f:
    pickle.dump(task_solution_list, f)
# Out:
# --------------------开始处理任务 1: 收集4Paradigm（06682.HK）的基本信息，包括公司简介、上市时间、股票代码、交易所等基础资料   --------------------
#
# 最相关的数据块编号: ['1', '2', '3', '5', '6']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 一、公司基本信息
#
# **4Paradigm（第四范式，股票代码：06682.HK）** 是中国领先的人工智能技术企业，专注于企业级AI平台的研发与应用。公司于 **2023年9月28日** 在香港联合交易所主板上市，股票代码 **06682.HK**。以下为核心基础资料：
#
# | **项目**         | **内容**                                  |
# |------------------|------------------------------------------|
# | 公司全称         | 北京第四范式智能技术股份有限公司          |
# | 英文名称         | Beijing Fourth Paradigm Technology Co., Ltd. |
# | 上市时间         | 2023年9月28日                            |
# | 交易所           | 香港联合交易所（HKEX）                    |
# | 股票代码         | 06682.HK                                 |
# | 所属行业         | 资讯科技业 - 软件服务 - 数码解决方案服务  |
# | 主营业务         | 销售自主研发的AI平台（"先知平台"）及即用型产品，并提供应用开发等服务，覆盖中国及海外市场 |
#
# ---
#
# ### 二、近期股价表现与交易数据（2025年1月-6月）
# 公司股价波动显著，反映市场对AI赛道的高关注度与风险偏好变化。关键数据如下：
#
# | 日期       | 开盘价(港元) | 收盘价(港元) | 最高价(港元) | 最低价(港元) | 成交量(股) | 成交额(港元) | 涨跌幅(%) | 振幅(%) |
# |------------|-------------|-------------|-------------|-------------|------------|--------------|-----------|---------|
# | 2025-01-28 | 50.95       | 50.10       | 52.85       | 38.50       | 125,965,169| 5,522,599,330 | -1.67     | 28.16   |
# | 2025-02-28 | 50.10       | 43.00       | 63.00       | 41.80       | 301,054,578| 16,300,643,808| -14.17    | 42.32   |
# | 2025-03-31 | 43.75       | 45.50       | 54.60       | 42.05       | 137,503,599| 6,650,743,836 | +5.81     | 29.19   |
# | 2025-04-30 | 47.65       | 40.55       | 48.65       | 33.50       | 93,628,562 | 3,687,792,976 | -10.88    | 33.30   |
# | 2025-05-30 | 40.55       | 43.05       | 49.55       | 38.50       | 101,748,950| 4,434,794,726 | +6.17     | 27.25   |
# | 2025-06-30 | 43.00       | 51.40       | 54.95       | 40.90       | 125,840,828| 6,126,044,570 | +19.40    | 32.64   |
#
# **股价分析**：
# - **波动性突出**：单月振幅最高达42.32%（2025年2月），反映市场对AI行业的情绪敏感。
# - **成交活跃**：2025年2月成交量突破3亿股，成交额达163亿港元，显示资金博弈激烈。
# - **阶段性复苏**：2025年6月收盘价较5月上涨19.40%，可能受益于行业政策或业绩预期改善。
#
# ---
#
# ### 三、关键财务结构趋势（2018-2023年）
# 基于资产负债表数据，公司财务结构呈现以下演变：
#
# | 报告日期   | 总资产(港元) | 总负债(港元) | 净资产(港元) | 流动比率<sup>①</sup> | 资产负债率(%) |
# |------------|--------------|--------------|--------------|----------------------|---------------|
# | 2018-12-31 | 981,107,000  | 713,647,000  | -267,460,000 | 0.86                 | 72.75%        |
# | 2019-12-31 | 2,028,908,000| 1,376,375,000| -652,533,000 | 0.86                 | 67.84%        |
# | 2020-12-31 | 3,199,008,000| 2,016,009,000| -1,182,999,000| 1.03                 | 63.02%        |
# | 2021-12-31 | 6,696,697,000| 6,448,684,000| -248,013,000 | 0.90                 | 96.30%        |
# | 2022-12-31 | 8,179,995,000| 6,718,984,000| -1,461,011,000| 0.95                 | 82.13%        |
# | 2023-12-31 | 7,147,274,000| 5,504,124,000| 5,452,514,000| 1.03                 | 77.01%        |
# | 2024-12-31 | 7,587,645,000| 5,090,140,000| 5,070,888,000| 1.12                 | 67.05%        |
#
# > *注①：流动比率 = 流动资产合计 / 流动负债合计*
#
# **财务分析**：
# 1. **净资产由负转正**：2023年净资产大幅跃升至54.53亿港元，标志公司进入盈利积累阶段。
# 2. **偿债能力优化**：流动比率从2018年的0.86提升至2024年的1.12，短期流动性压力显著缓解。
# 3. **杠杆率下降**：资产负债率从2021年的96.3%降至2024年的67.05%，财务结构趋于稳健。
#
# ---
#
# ### 四、结论与风险提示
# - **核心优势**：深耕AI平台化技术（先知平台），服务企业智能化转型需求，契合中国数字经济战略方向。
# - **风险关注**：
#   - **市场波动敏感**：股价高波动性反映行业估值分化，需警惕技术商业化不及预期的回调风险。
#   - **研发投入压力**：AI领域技术迭代迅速，持续高研发投入可能影响短期盈利表现。
# - **机会判断**：财务结构改善与净资产转正为长期发展奠定基础，若AI渗透率加速提升，公司平台化模式有望释放规模效应。
#
# > 数据来源：公司财务报表及公开市场交易数据（截至2025年6月30日）。
#
#
# --------------------开始处理任务 2: 提取并整理4Paradigm的三大会计报表（资产负债表、利润表、现金流量表）数据   --------------------
#
# 最相关的数据块编号: ['7', '8', '9']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 4Paradigm（06682.HK）三大会计报表数据分析
#
# #### 一、利润表分析（单位：千港元）
# 以下为2018-2024年度利润表关键数据摘要：
#
# | 报告日期   | 营业额       | 销售成本      | 毛利         | 研发费用      | 经营溢利       | 除税前溢利     | 股东应占溢利   | 每股基本盈利（港元） |
# |------------|--------------|---------------|--------------|---------------|----------------|----------------|----------------|----------------------|
# | 2018-12-31 | 127,750      | 73,163        | 54,587       | 193,159       | -336,027       | -372,262       | -367,960       | -1.96               |
# | 2019-12-31 | 459,518      | 259,437       | 200,081      | 416,418       | -550,943       | -716,723       | -716,576       | -3.82               |
# | 2020-12-31 | 942,238      | 512,503       | 429,735      | 565,674       | -560,066       | -749,483       | -749,650       | -4.00               |
# | 2021-12-31 | 2,018,399    | 1,064,924     | 953,475      | 1,249,485     | -1,172,806     | -1,791,699     | -1,785,655     | -7.63               |
# | 2022-12-31 | 3,082,637    | 1,595,991     | 1,486,646    | 1,650,010     | -1,025,902     | -1,665,094     | -1,644,897     | -6.15               |
# | 2023-12-31 | 4,204,142    | 2,224,594     | 1,979,548    | 1,768,996     | -545,434       | -930,829       | -908,717       | -2.80               |
# | 2024-12-31 | 5,260,650    | 3,015,821     | 2,244,829    | 2,169,767     | -355,082       | -290,088       | -268,788       | -0.58               |
#
# **核心结论：**
# 1. **营收高速增长**：营业额从2018年的1.28亿港元增至2024年的52.61亿港元，年复合增长率（CAGR）达81.3%，反映业务扩张迅猛。
# 2. **亏损收窄趋势显著**：2023年起亏损大幅改善，经营溢利从2021年低点-117.28亿港元收窄至2024年-35.51亿港元；2024年股东应占亏损同比减少84.1%，体现降本增效成效。
# 3. **研发投入持续高企**：研发费用年均占营收40%以上（2023年占比42.1%），表明公司长期聚焦技术投入。
# 4. **毛利率波动下行**：毛利率从2018年42.7%降至2024年42.7%，主要因业务规模化过程中成本上升。
#
# ---
#
# #### 二、现金流量表分析（单位：千港元）
# 以下为2018-2024年度现金流量表关键数据摘要：
#
# | 报告日期   | 经营业务现金净额 | 投资业务现金净额 | 融资业务现金净额 | 现金净额   | 期初现金   | 期末现金   |
# |------------|------------------|------------------|------------------|------------|------------|------------|
# | 2018-12-31 | -197,983         | -328,787         | 545,647          | 18,100     | 707,500    | 394,658    |
# | 2019-12-31 | -311,336         | -357,058         | 1,028,766        | 360,372    | 394,658    | 703,786    |
# | 2020-12-31 | -365,906         | -592,023         | 969,265          | 11,336     | 703,786    | 1,052,073  |
# | 2021-12-31 | -580,000         | -3,969,619       | 4,283,540        | -266,079   | 1,052,073  | 1,292,686  |
# | 2022-12-31 | -549,060         | -221,620         | -90,140          | -860,820   | 1,292,686  | 1,326,818  |
# | 2023-12-31 | -402,467         | -275,170         | 930,719          | 253,082    | 1,326,818  | 1,977,891  |
# | 2024-12-31 | -221,664         | -1,096,169       | -30,931          | -1,348,764 | 1,977,891  | 858,618    |
#
# **核心结论：**
# 1. **经营现金流改善**：经营现金净流出从2021年峰值-58.00亿港元收窄至2024年-22.17亿港元，运营效率提升。
# 2. **投资活动激进**：2021年投资现金净流出达396.96亿港元（主因战略收购及资产构建），2024年投资流出扩大至109.62亿港元，显示持续资本布局。
# 3. **融资依赖度高**：2019-2023年融资现金净流入合计77.36亿港元，但2024年转为净流出3.09亿港元，融资能力面临考验。
# 4. **现金储备承压**：期末现金从2023年19.78亿港元骤降至2024年8.59亿港元，现金净流出134.88亿港元，需关注流动性风险。
#
# ---
#
# #### 三、股东权益关键指标分析
# 以下为2018-2024年度股东权益相关数据摘要：
#
# | 报告日期   | 每股净资产（港元） | 每股基本盈利（港元） | 股东应占溢利（千港元） |
# |------------|--------------------|----------------------|------------------------|
# | 2018-12-31 | -0.54              | -1.96               | -367,960              |
# | 2019-12-31 | -1.31              | -3.82               | -716,576              |
# | 2020-12-31 | -2.39              | -4.00               | -749,650              |
# | 2021-12-31 | -0.71              | -7.63               | -1,785,655            |
# | 2022-12-31 | -3.19              | -6.15               | -1,644,897            |
# | 2023-12-31 | 10.84              | -2.80               | -908,717              |
# | 2024-12-31 | 10.26              | -0.58               | -268,788              |
#
# **核心结论：**
# 1. **净资产由负转正**：每股净资产从2022年-3.19港元跃升至2023年10.84港元，主要受益于融资活动充实资本。
# 2. **盈利改善明显**：每股亏损从2021年-7.63港元收窄至2024年-0.58港元，股东应占溢利亏损减少84.1%（2023-2024）。
# 3. **长期挑战仍存**：尽管趋势向好，但连续7年亏损反映商业模式仍处投入期，需持续验证盈利拐点。
#
# ---
#
# ### 综合财务趋势与风险提示
# - **积极信号**：营收高增长、亏损收窄、净资产转正表明业务步入良性轨道，技术投入开始转化效率。
# - **核心风险**：
#   1. **流动性压力**：2024年现金储备腰斩，若融资环境恶化可能影响研发投入连续性；
#   2. **盈利不确定性**：毛利率下滑与高研发支出导致盈利周期拉长；
#   3. **投资激进性**：大规模投资活动现金流消耗过快，需警惕资产回报不及预期风险。
# - **策略建议**：优先保障现金流安全，优化成本结构，并聚焦高毛利产品加速盈利拐点到来。
#
#
# --------------------开始处理任务 3: 分析公司主营业务、核心竞争力与行业地位，包括市场份额、技术优势、客户群体等   --------------------
#
# 最相关的数据块编号: ['3', '5', '12', '13', '14', '15']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 公司主营业务、核心竞争力与行业地位分析
#
# #### 一、主营业务概述
# 第四范式（06682.HK）专注于人工智能驱动的企业级软件服务，核心业务为提供端到端AI解决方案，涵盖决策优化、智能风控、运营效率提升等场景。公司隶属于“资讯科技业—软件服务—数码解决方案服务”细分行业，通过自主研发的AI平台（如Prophet AIOS）赋能金融、零售、制造等垂直领域客户，实现数据驱动的智能化转型。其服务模式包括标准化SaaS产品与定制化解决方案，收入主要来源于软件订阅费及项目实施费。
#
# #### 二、核心竞争力分析
# 1. **技术优势**：
#    公司依托深度学习、AutoML（自动机器学习）等核心技术，构建了高壁垒的AI平台。其核心系统支持低代码开发，显著降低企业AI部署门槛；同时，平台具备实时数据处理能力，在金融风控等高频场景中表现突出。研发投入持续高位（2024年报销售成本31.97亿港元，占营收57.3%），支撑技术迭代。相较同行，第四范式在算法效率与场景适配性上具备差异化优势，例如在金融领域反欺诈模型中的准确率领先行业平均水准。
#
# 2. **客户群体与粘性**：
#    客户以大型金融机构和头部企业为主，包括银行、保险及零售巨头。2024年年报显示，公司实现营业收入55.77亿港元，同比增长显著（较2024中报19.98亿港元环比提升179%），反映客户需求扩张及复购率提升。高净值客户（如金融业）占比超60%，合同周期多为3年期以上，客户粘性强。行业数据表明，其解决方案在金融细分市场的渗透率居前，但具体份额未公开披露。
#
# 3. **财务韧性**：
#    尽管公司处于战略投入期导致亏损（2024年税后利润-1.81亿港元，主营利润率-5.88%），但资产负债率仅21.39%（2024中报数据），显著低于行业均值（52家企业中位数为46.58%），显示低杠杆运营和稳健的资产结构。流动资产充裕（52.04亿港元），支撑长期研发投入。
#
# #### 三、行业地位与市场份额
# 1. **行业定位**：
#    在“数码解决方案服务”细分赛道（52家企业），第四范式属中上游技术驱动型厂商。以资产规模计（70.83亿港元），公司位列行业前30%，落后于腾讯（17707.35亿港元）等巨头，但领先于创新奇智（32.82亿港元）等垂直AI服务商。在AI专项解决方案领域，其与商汤（00020.HK）、创新奇智（02121.HK）形成直接竞争，但技术聚焦点差异明显——第四范式强于决策优化，商汤侧重计算机视觉。
#
# 2. **市场份额与竞争格局**：
#    基于2024年财务数据，公司在AI解决方案细分市场的份额约5%–8%（估算依据：营收55.77亿港元占行业总营收约1.5%–2.5%，行业头部集中度高）。核心竞争优势在于：
#    - **技术壁垒**：AutoML专利数量行业前三，平台兼容性优于同业。
#    - **垂直深耕**：金融行业市占率约15%（第三方机构估算），领先于多数同行。
#    - **增长动能**：2024年营收增速超行业平均（行业营收中位数增速约10%，公司全年同比增约30%）。
#
#    下表对比关键同业财务表现（2024年报数据），突显第四范式的规模与效率特征：
#
# | 股票代码 | 股票简称     | 营业收入（亿港元） | 税后利润（亿港元） | 资产负债率（%） | 主营利润率（%） |
# |----------|--------------|---------------------|---------------------|-------------------|-------------------|
# | 06682    | 第四范式     | 55.77               | -1.81               | 21.39             | -5.88             |
# | 00020    | 商汤-W       | 39.99               | -26.50              | 30.25             | -112.94           |
# | 02121    | 创新奇智     | 12.95               | -1.98               | 31.87             | -51.15            |
# | 00700    | 腾讯控股     | 6999.38             | 973.84              | 43.95             | 32.13             |
# | 09660    | 地平线机器人 | 25.27               | -54.55              | 299.40            | -74.19            |
#
# 数据来源：2024年报行业财务经营数据。
# 注：腾讯控股为行业龙头，地平线机器人代表高亏损技术厂商。
#
# 3. **市场认可度**：
#    机构评级持续积极，2025年6月海通国际等5家机构给予“买入”或“增持”评级，目标价最高90.84港元（较当前股价溢价76.7%），反映市场对其技术潜力与增长前景的乐观预期。股价波动性较高（2025年振幅最高42.32%），但长期呈上行趋势（2025年6月收盘51.40港元，较1月上涨2.6%）。
#
# #### 四、结论性判断
# - **趋势与机会**：公司处于高速增长期，技术优势驱动金融等核心行业份额提升；AI解决方案市场年增速超20%，叠加政策支持（如“数字经济”战略），公司有望受益于行业红利。机构目标价隐含上行空间，反映盈利改善预期。
# - **风险**：持续亏损（2024年ROE -5.09%）及负现金流（每股现金流-1.42港元）可能制约短期扩张；行业竞争加剧（如腾讯、商汤资源碾压），需警惕市场份额挤压。
# - **战略建议**：强化垂直行业渗透，优化成本结构以实现盈亏平衡，同时利用低负债优势加大研发投入，巩固技术护城河。
#
#
# --------------------开始处理任务 4: 计算关键财务比率（如ROE、毛利率、现金流匹配度等），并与行业同行进行对比分析   --------------------
#
# 最相关的数据块编号: ['10', '12', '14', '7', '8', '9']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 第四范式（06682.HK）关键财务比率分析与同业对比
#
# #### 一、核心财务比率计算与分析（2024年）
# 基于2024年年报数据，第四范式关键财务指标如下：
# 1. **毛利率**：42.7%（2023年：47.1%），同比小幅下降4.4个百分点，但总体保持平稳。
# 2. **ROE（净资产收益率）**：-5.16%，较2023年（-48.15%）显著改善，反映亏损大幅收窄。
# 3. **现金流匹配度**（经营现金流净额/净利润）：-1.34倍（经营现金流净额-2.96亿元，净利润-2.69亿元），较2023年（-2.14倍）有所优化。
# 4. **研发费用率**：41.2%，持续高投入以维持技术领先性。
# 5. **净亏损率**：-5.1%（归属母公司净亏损/营收），同比缩窄70.4%，连续4年减亏。
#
# **趋势分析**：公司毛利率稳定在40%以上，印证平台化产品的定价能力；ROE与现金流匹配度同步改善，反映经营效率提升；研发高投入（41.2%）支撑“AI Agent+垂直世界模型”战略落地，为长期增长奠基。
#
# ---
#
# #### 二、行业同业对比分析（2024年中报数据）
# 选取港股“数码解决方案服务”行业52家可比公司中报数据对比：
#
# | **指标**         | **第四范式** | **行业中位数** | **行业前3名代表**         | **第四范式排名** |
# |------------------|--------------|----------------|---------------------------|------------------|
# | **毛利率(%)**    | 42.7*        | 9.3            | 腾讯控股(32.9%)           | 第8位            |
# | **ROE(%)**       | -5.16*       | -4.75          | 腾讯控股(10.6%)           | 中下游           |
# | **净利率(%)**    | -5.1*        | -6.2           | 中国民航信息(40.4%)       | 中等水平         |
# | **研发费用率(%)**| 41.2*        | 未披露         | 创新奇智(32.7%，年报参考) | 显著高于同业     |
#
# > 注：带`*`为2024年报数据，其余为2024中报行业数据；毛利率排名基于中报行业可比数据推算。
#
# **关键结论**：
# 1. **毛利率优势突出**：42.7%的毛利率远超行业中位数（9.3%），在52家公司中排名第8，接近龙头腾讯控股（32.9%），体现技术平台业务的溢价能力。
# 2. **盈利改善显著**：净亏损率（-5.1%）优于行业中位数（-6.2%），ROE（-5.16%）接近行业中游水平，减亏趋势明确。
# 3. **研发强度领跑行业**：41.2%的研发费用率显著高于同业（如创新奇智32.7%），反映对AI技术创新的持续押注。
# 4. **现金流压力仍存**：现金流匹配度（-1.34倍）差于行业龙头（腾讯控股OCF/净利润=1.41倍），但优于商汤-W（-2.3倍）等亏损较大的同行。
#
# ---
#
# #### 三、财务趋势与风险提示（2018-2024）
# **财务比率趋势表**：
# | 年份   | ROE(%) | 毛利率(%) | 净利率(%) | 研发费用率(%) | 现金流匹配度(倍) |
# |--------|---------|-----------|-----------|---------------|------------------|
# | 2024   | -5.16   | 42.7      | -5.1      | 41.2          | -1.34            |
# | 2023   | -48.15  | 47.1      | -21.6     | 42.1*         | -2.14            |
# | 2022   | 170.83* | 48.2      | -53.4     | 53.5*         | -1.78            |
# | 2021   | 233.56* | 47.2      | -88.4     | 61.9*         | -1.76            |
# > 注：带`*`的ROE因早期净资产为负失去可比性；研发费用率按年报成本结构估算。
#
# **核心趋势**：
# - **盈利结构优化**：毛利率稳定在40%+高位，净亏损率从2021年-88.4%收窄至2024年-5.1%，逼近盈亏平衡点。
# - **研发效率提升**：研发费用率从2021年61.9%降至41.2%，单位研发投入的营收产出提高。
# - **现金流改善**：经营现金流/净利润比值从-1.76倍升至-1.34倍，营运资金管理能力增强。
#
# **风险提示**：
# 1. **盈利可持续性**：尽管亏损收窄，但净利润率仍未转正，需关注规模化盈利路径。
# 2. **现金流压力**：经营现金流尚未覆盖亏损，若融资环境收紧可能影响研发投入强度。
# 3. **行业竞争加剧**：毛利率较2023年下降4.4个百分点，需警惕同业价格竞争对盈利空间的挤压。
#
# ---
#
# #### 四、结论
# 第四范式在**技术溢价（高毛利率）** 和 **研发壁垒（41.2%费用率）** 上具备显著优势，盈利能力的持续改善（ROE从-48%升至-5.16%）反映战略转型成效。相较同业，公司处于行业中上游水平，但需加速实现现金流自给以支撑长期投入。随着AI Agent平台收入高增（2024年+46.7%），叠加端侧AI等新增长点落地，盈利转正可期。
#
#
# --------------------开始处理任务 5: 选取可比公司进行横向竞争分析，包括财务表现、市场定位、技术能力等   --------------------
#
# 最相关的数据块编号: ['3', '4', '12', '13', '14', '15']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 横向竞争分析：4Paradigm（06682.HK）与可比公司对比
#
# #### **一、可比公司选取依据**
# 基于行业分类（资讯科技业-软件服务-数码解决方案服务）及业务相似性（人工智能平台与解决方案），选取以下可比公司：
# - **商汤-W（00020）**：计算机视觉AI龙头
# - **创新奇智（02121）**：制造业AI解决方案提供商
# - **金融壹账通（06638）**：金融科技AI平台
# - **出门问问（02438）**：对话式AI与生成式AI企业
# - **声通科技（02495）**：交互式AI解决方案商
# - **腾讯控股（00700）**（参考标杆）：综合科技巨头，含AI业务
#
# ---
#
# #### **二、财务表现对比（2024年中报数据）**
# | **股票代码** | **股票简称**       | **营收(亿港元)** | **毛利率(%)** | **净利率(%)** | **资产负债率(%)** |
# |--------------|--------------------|------------------|---------------|---------------|-------------------|
# | **06682**     | **第四范式**       | 19.98            | 42.3          | -9.06         | **21.39**         |
# | 00020        | 商汤-W             | 18.62            | 44.1          | -142.3        | 30.25             |
# | 02121        | 创新奇智           | 6.12             | **33.8**      | -32.4         | 31.87             |
# | 06638        | 金融壹账通         | 15.62            | 36.4          | -9.21         | 45.33             |
# | 02438        | 出门问问           | 1.74             | 64.4          | -356.5        | 33.43             |
# | 02495        | 声通科技           | 3.97             | 43.6          | -158.9        | **135.51**        |
# | 00700        | 腾讯控股（参考）   | **3430.45**      | **52.9**      | **28.4**      | 43.95             |
#
# **关键结论：**
# 1. **营收规模**：第四范式（19.98亿港元）居行业中上游，显著高于垂直领域AI公司（出门问问、声通科技），但远低于腾讯。
# 2. **盈利能力**：
#    - **毛利率优势**：第四范式（42.3%）高于行业均值，反映技术平台化带来的成本控制能力。
#    - **净亏损可控**：净利率（-9.06%）优于商汤-W（-142.3%）、出门问问（-356.5%）等，反映更稳健的变现能力。
# 3. **财务健康度**：资产负债率（21.39%）为行业最低水平之一，显著低于声通科技（135.51%）、金融壹账通（45.33%），抗风险能力突出。
#
# ---
#
# #### **三、市场定位与技术能力对比**
# | **维度**       | **第四范式**                            | **主要可比公司差异点**                              |
# |----------------|-----------------------------------------|-----------------------------------------------------|
# | **核心定位**   | 平台为中心的决策类AI领导者              | 商汤-W：侧重视觉AI；金融壹账通：垂直金融场景        |
# | **技术壁垒**   | 自动机器学习算法（OGB两项世界纪录保持者）| 创新奇智：制造业Know-How整合；出门问问：生成式AI    |
# | **商业化场景** | 跨行业企业级决策优化（金融/零售/制造）  | 声通科技：客服交互场景；腾讯：消费端+企业端综合布局 |
#
# **技术优势验证**：
# - 第四范式自动机器学习算法在OGB任务中打破Facebook、阿里巴巴等机构纪录，技术可靠性获国际背书。
# - 对比出门问问（生成式AI）和商汤-W（视觉大模型），第四范式聚焦“决策类AI”，差异化定位企业核心业务流程优化。
#
# ---
#
# #### **四、机构评级与投资价值**
# **近期评级动态（2025年5月）**：
# | **机构名称**       | **评级** | **目标价(港元)** | **趋势** |
# |---------------------|----------|-------------------|----------|
# | 国泰海通证券        | 买入     | 90.84             | --       |
# | 中信证券            | 买入     | 57.00             | 不变     |
# | 长江证券            | 买入     | --                | --       |
# | 交银国际证券        | 增持     | 64.00             | 不变     |
#
# **结论**：
# - **一致看好技术壁垒**：头部券商均给予“买入/增持”评级，目标价最高90.84港元（国泰海通），反映对平台化AI解决方案增长潜力的认可。
# - **行业风险提示**：可比公司中除腾讯外普遍亏损（如商汤/出门问问净利率<-100%），需关注第四范式规模化降本进度。
#
# ---
#
# ### **总结：竞争地位与核心优势**
# 1. **财务健康度领先**：低负债率（21.39%）与可控亏损（净利率-9.06%）在AI解决方案商中稀缺；
# 2. **技术差异化明确**：决策类AI平台龙头，自动机器学习算法为全球第一梯队；
# 3. **商业化潜力**：跨行业企业客户覆盖能力优于垂直领域同行（如金融壹账通/声通科技）。
# **风险提示**：行业整体盈利周期较长，需持续跟踪营收增速与亏损收窄节奏。
#
#
# --------------------开始处理任务 6: 构建估值模型（如DCF、PE等），并对关键变量（如原材料成本、汇率变动）进行敏感性分析   --------------------
#
# 最相关的数据块编号: ['7', '8', '9', '10', '11', '17']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 估值模型构建与关键变量敏感性分析
#
# #### 一、估值模型选择与构建
# 鉴于第四范式（06682.HK）尚未实现盈利（2024年归属母公司亏损2.69亿元），传统PE估值法适用性有限。本报告采用**市销率（PS）估值法**为主，辅以**贴现现金流（DCF）模型**进行交叉验证。
#
# ##### 1. 市销率（PS）估值
# 参考港股软件服务行业（数码解决方案服务）52家可比公司数据（表1），行业平均PS为**19.54倍**（剔除极端值后计算）。结合公司2024年财务表现：
# - **营业收入**：52.61亿元（人民币，下同），同比增长25.1%；
# - **核心业务增速**：先知AI平台收入36.76亿元（占比69.9%），同比增46.7%。
#
# **估值计算**：
# 合理PS取行业均值19.54倍，则公司合理市值 = 52.61 × 19.54 ≈ **1,027.6亿元**（约1,117亿港元）。需注意该估值隐含对公司持续高增长的预期，需通过DCF模型验证可持续性。
#
# ##### 2. 贴现现金流（DCF）模型
# 采用三阶段模型，关键假设如下：
# - **高速增长期（5年）**：营收增速25%（2025–2027年）、20%（2028–2029年），反映AI平台业务扩张潜力；
# - **过渡期（5年）**：增速线性降至永续增长率5%；
# - **永续增长率**：5%，与长期经济增速匹配；
# - **利润率改善**：2028年扭亏（营业利润率8%），2030年提升至15%，永续期20%；
# - **WACC**：12.4%（股权成本14.75%，债务成本6%，债务占比20%）；
# - **自由现金流（FCFF）**：基于营业利润调整资本支出及营运资本变动。
#
# **估值结果**：
# 股权价值约**169.2亿港元**（对应股价36.3港元），反映市场需平衡高增长与盈利不确定性。
#
# #### 二、关键变量敏感性分析
# ##### 1. 毛利率波动影响
# 2024年毛利率为42.7%，其变动对净利润敏感度高（表2）：
#
# **表2：毛利率变动对净利润的敏感性分析（2024年）**
# | 毛利率变动 | 毛利润（亿元） | 净利润（亿元） | 变动幅度 |
# |------------|----------------|----------------|----------|
# | -5%        | 20.33          | -3.79          | -40.9%   |
# | -2%        | 21.89          | -3.24          | -20.4%   |
# | **基准**   | **22.45**      | **-2.69**      | **0%**   |
# | +2%        | 23.01          | -2.14          | +20.4%   |
# | +5%        | 24.11          | -1.29          | +52.0%   |
#
# **结论**：
# - 毛利率每下降1%，净利润减少约0.22亿元。主要风险来自**GPU成本上升**（英伟达芯片进口占原材料成本超30%），若美国出口管制加严或全球芯片短缺，毛利率可能承压。
#
# ##### 2. 汇率变动影响
# 公司收入以人民币计价，但部分采购以美元结算（如GPU进口）。人民币兑美元汇率波动对成本的影响如下（表3）：
#
# **表3：人民币汇率变动对净利润的敏感性分析**
# | 人民币贬值幅度 | 成本增加（亿元） | 净利润（亿元） | 变动幅度 |
# |----------------|------------------|----------------|----------|
# | -5%            | 0.45             | -3.14          | -16.7%   |
# | -2%            | 0.18             | -2.87          | -6.7%    |
# | **基准**       | **0**            | **-2.69**      | **0%**   |
# | +2%            | -0.18            | -2.51          | +6.7%    |
# | +5%            | -0.45            | -2.24          | +16.7%   |
#
# **结论**：
# - 人民币每贬值1%，净利润减少约0.09亿元。需警惕美联储加息周期下美元走强的潜在冲击。
#
# #### 三、估值结论与风险提示
# 1. **估值结论**：
#    - PS法（1,117亿港元）反映市场对AI赛道的高增长溢价，但DCF法（169亿港元）提示盈利兑现不确定性。当前股价或已部分透支短期预期，建议结合盈利拐点动态评估。
#
# 2. **核心风险**：
#    - **技术迭代**：AI行业技术更新迅速，若公司无法保持先知平台的领先性，市场份额可能被侵蚀；
#    - **政策监管**：数据安全法规趋严可能限制业务拓展；
#    - **成本控制**：GPU价格波动及汇率风险可能延缓盈利改善进程。
#
# 3. **投资建议**：
#    短期维持**"持有"**评级，重点关注2025年两大催化剂：
#    - **AI agent与垂直模型融合进展**：若落地场景超预期，可能打开估值空间；
#    - **端侧AI业务放量**：ModelHub AIoT解决方案有望受益于2025年"端侧AI元年"需求爆发。
#
# > **附：行业可比公司PS估值参考（2024年）**
# > | 股票代码 | 公司简称         | PS（倍） |
# > |----------|------------------|----------|
# > | 00700    | 腾讯控股         | 22.76    |
# > | 00354    | 中国软件国际     | 27.89    |
# > | 00856    | 伟仕佳杰         | 12.29    |
# > | 00696    | 中国民航信息网络 | 16.23    |
# > | **行业平均** |                  | **19.54**|
#
# （注：货币单位已统一换算为港元；数据来源：2024年报行业价值表现数据）
#
#
# --------------------开始处理任务 7: 评估公司治理结构与管理层信息，包括董事会构成、管理层背景、股权结构等   --------------------
#
# 最相关的数据块编号: ['5', '12', '13', '14', '15', '16']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 公司治理结构与管理层信息评估
#
# 本章节旨在系统评估4Paradigm（06682.HK）的公司治理结构与管理层信息，包括董事会构成、管理层背景及股权结构等核心要素。然而，基于所提供的参考数据和信息，未包含直接涉及公司治理细节（如董事会成员名单、管理层履历或股权分布明细）的内容。因此，本报告将聚焦于可验证的财务数据、行业比较及市场评级，通过公司财务表现和资本结构间接评估管理效率与治理稳健性。所有分析均严格基于用户提供的参考信息，未添加任何编造数据。
#
# #### 一、股权结构与资本基础
# 从2024年中报行业价值表现数据可见，4Paradigm的总股本为4.66亿股（截至2024年中报），在行业内处于中等规模。公司资产总计70.83亿元，其中流动资产52.04亿元，负债合计15.15亿元，资产负债率21.39%，显著低于行业均值（行业52家企业中位数为46.58%）。这表明公司资本结构较为稳健，负债水平可控，可能反映管理层在财务杠杆运用上的审慎策略。以下为关键股权与财务指标与行业对比（基于2024年中报数据）：
#
# | 股票代码 | 股票简称     | 总股本（亿股） | 资产总计（亿元） | 负债合计（亿元） | 资产负债率（%） | 税后利润（亿元） |
# |----------|--------------|----------------|------------------|------------------|------------------|------------------|
# | 06682    | 第四范式     | 4.66           | 70.83            | 15.15            | 21.39            | -1.81            |
# | 00700    | 腾讯控股     | 93.55          | 17,707.35        | 7,782.53         | 43.95            | 973.84           |
# | 00020    | 商汤-W       | 351.42         | 348.27           | 105.35           | 30.25            | -26.50           |
# | 行业均值 | -            | 35.21          | 1,200.65         | 560.38           | 46.58            | -5.32            |
#
# **分析结论**：
# - 4Paradigm的股权规模（4.66亿股）小于行业龙头（如腾讯控股93.55亿股），但资产负债率（21.39%）优于行业均值（46.58%），凸显其低负债运营模式。这暗示管理层在资本配置上偏向保守，可能降低财务风险，但也可能限制扩张速度。
# - 税后利润为负（-1.81亿元），与行业多数企业一致（行业亏损企业中位数-1.86亿元），反映数码解决方案服务板块整体盈利承压，需关注管理层未来扭亏策略。
#
# #### 二、财务表现与管理效率
# 基于2024年报及中报财务经营数据，4Paradigm的营收增长与盈利指标揭示管理层运营能力。2024年，公司营业收入55.77亿元（年报数据），销售毛利23.80亿元，但主营利润率-5.88%，显示核心业务尚未盈利。2024年中报进一步显示营业收入19.98亿元，主营利润率-8.85%，亏损持续但幅度收窄（税后利润从年报-1.81亿元改善至中报-1.81亿元，需注意中报为半年度数据）。关键财务指标如下：
#
# **2024年报财务指标对比（行业精选）**：
# | 股票代码 | 股票简称     | 基本每股收益（元） | 每股净资产（元） | 净资产收益率（%） | 营业收入（亿元） | 主营利润率（%） |
# |----------|--------------|---------------------|-------------------|---------------------|------------------|------------------|
# | 06682    | 第四范式     | -0.61              | 11.52             | -5.09               | 55.77            | -5.88            |
# | 00700    | 腾讯控股     | 22.20              | 111.88            | 21.51               | 6,999.38         | 32.13            |
# | 00020    | 商汤-W       | -0.14              | 0.67              | -18.10              | 39.99            | -112.94          |
# | 行业均值 | -            | -0.85              | 5.43              | -12.75              | 420.18           | -15.62           |
#
# **2024中报财务指标对比（行业精选）**：
# | 股票代码 | 股票简称     | 基本每股收益（元） | 每股净资产（元） | 净资产收益率（%） | 营业收入（亿元） | 主营利润率（%） |
# |----------|--------------|---------------------|-------------------|---------------------|------------------|------------------|
# | 06682    | 第四范式     | -0.35              | 11.90             | -2.84               | 19.98            | -8.85            |
# | 00700    | 腾讯控股     | 10.26              | 98.44             | 10.60               | 3,430.45         | 32.89            |
# | 00020    | 商汤-W       | -0.09              | 0.69              | -10.59              | 18.62            | -141.24          |
# | 行业均值 | -            | -0.42              | 4.96              | -8.35               | 210.75           | -18.47           |
#
# **分析结论**：
# - 管理效率趋势：公司净资产收益率（ROE）从2024年报的-5.09%改善至2024中报的-2.84%，主营利润率从-5.88%小幅恶化至-8.85%（中报），显示管理层在成本控制上取得初步成效（ROE提升），但营收增长未能有效转化为盈利，核心业务仍面临压力。对比行业，4Paradigm的每股净资产（11.52元）高于均值（5.43元），反映资产质量较优，可能源于技术资产积累。
# - 风险与机会：持续亏损（每股收益均为负值）暴露盈利模式风险，需管理层加速商业化落地。然而，低负债率（21.39%）提供缓冲空间，评级机构一致看好（见下文），暗示市场对管理层战略抱有信心。
#
# #### 三、市场评级与管理层战略认可度
# 评级信息显示，多家机构对4Paradigm维持积极评价，目标价均高于当前股价（2025年6月收盘价51.4港元）。2025年6月以来，海通国际上调目标价至90.84港元，突显对管理层执行力的认可。关键评级汇总如下：
#
# | 日期       | 机构名称         | 最新评级 | 同机构前次评级 | 目标价（港元） | 较上期变化 |
# |------------|------------------|----------|----------------|----------------|------------|
# | 2025-06-17 | 海通国际       | 增持     | 增持           | 90.84          | 上升       |
# | 2025-05-25 | 国泰海通证券   | 买入     | --             | 90.84          | --         |
# | 2025-05-22 | 交银国际证券   | 增持     | 增持           | 64.00          | 不变       |
# | 2025-05-19 | 中信证券       | 买入     | 买入           | 57.00          | 不变       |
# | 2025-04-02 | 国投证券       | 买入     | 买入           | 71.76          | 下降       |
#
# **分析结论**：
# - 机构一致给予“买入”或“增持”评级，目标价中位数71.76港元（较2025年6月收盘价51.4港元溢价39.6%），反映专业机构对管理层战略（如AI技术落地与市场扩张）的高度认可。海通国际目标价上调尤其强调盈利改善预期。
# - 结合预测信息，2025年纯利预测分歧较大（机构区间-121亿元至+86亿元），但2026–2027年一致转向盈利（如海通预测2026年纯利277.74亿元），显示管理层中长期战略被市场视为扭亏关键驱动力。
#
# #### 总体评估与展望
# 基于可用数据，4Paradigm的公司治理结构细节（如董事会构成）虽未披露，但其低负债资本结构（资产负债率21.39%）、稳健资产质量（每股净资产11.52元）及机构强力背书，表明管理层在财务风控与战略规划上具备较强能力。然而，持续亏损（主营利润率-8.85%）暴露核心业务盈利挑战，需董事会及管理层强化商业化效率。
# **投资建议**：短期关注盈利拐点（基于2026年盈利预测），长期治理风险可控，建议结合季度财报跟踪管理层执行进展。
#
#
# --------------------开始处理任务 8: 分析公司发展战略与未来规划，包括市场扩张、研发投入、合作项目等   --------------------
#
# 最相关的数据块编号: ['5', '12', '14', '16', '17']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 公司发展战略与未来规划分析
#
# 本章节聚焦4Paradigm（06682.HK）的发展战略与未来规划，涵盖市场扩张、研发投入及合作项目等核心维度。分析基于公司2024年中报行业数据、股票交易表现及机构预测信息，结合行业竞争格局（数码解决方案服务行业共52家企业），确保数据一致性与逻辑严谨性。公司作为AI解决方案提供商，当前处于战略投入期，未来增长潜力显著，但需关注短期亏损与行业竞争风险。
#
# #### 一、市场扩张战略
# 公司通过技术差异化加速市场渗透，重点布局高增长行业（如金融、零售）。2024年中报显示，公司营业收入19.98亿港元，在行业中排名居中（行业营收中位数约3.60亿港元），但销售毛利达8.45亿港元，毛利率42.3%（行业平均毛利率约15.2%），反映产品附加值较高。然而，主营利润率为-8.85%，表明市场扩张初期成本承压。
# 预测数据揭示积极扩张态势：2025年多家券商预期营收增长，目标价区间55-90港元（如海通证券目标价90.84港元），2026-2027年纯利预测大幅跃升（大和证券2027年纯利预测1084亿港元）。趋势表明，公司正通过垂直行业深耕（如金融科技）和区域拓展（如东南亚市场）实现规模增长，但需警惕行业竞争加剧风险（腾讯控股等巨头市占率高）。
#
# #### 二、研发投入分析
# 公司持续强化研发投入以维持技术领先，2024年中报显示净亏损1.81亿港元，净资产收益率-2.84%，每股现金流-0.92港元，均低于行业均值（行业平均净资产收益率-5.2%，每股现金流0.05港元）。高研发强度是亏损主因，但支撑长期竞争力：
# - **投入规模**：销售成本11.52亿港元（占营收57.7%），显著高于行业平均销售成本占比（约45%），反映研发资源倾斜。
# - **产出潜力**：预测数据佐证研发转化效率，2026年每股盈利预测均值52.2元（海通证券56.0元），较2025年增长375%，表明AI模型优化与产品迭代将逐步兑现收益。机会在于生成式AI等新兴技术布局，风险为研发周期延长可能加剧现金流压力。
#
# #### 三、合作项目与生态构建
# 公司通过战略合作拓展生态圈，重点覆盖技术协同与客户渠道。行业数据显示资产负债率仅21.39%（行业平均53.8%），流动资产52.04亿港元，提供充足合作资金保障。虽无具体项目披露，但趋势清晰：
# - **技术合作**：与云计算厂商（如腾讯控股）及硬件供应商整合AI算力，降低部署成本。
# - **行业联盟**：在金融、医疗领域建立标杆案例（参考金融壹账通等同业模式），提升解决方案渗透率。
# 合作强化了规模化交付能力，但依赖外部伙伴可能引致供应链风险。
#
# #### 四、未来规划与综合展望
# 公司规划聚焦盈利拐点突破与全球化布局。基于预测，2025年为过渡期（券商目标价分歧显著，反映短期不确定性），2026年起进入高速增长阶段：
#
# **2025-2027年核心预测指标汇总表**
# | 财政年度 | 纯利/亏损预测（亿港元） | 每股盈利预测（港元） | 券商       | 评级     | 目标价（港元） |
# |----------|--------------------------|----------------------|------------|----------|----------------|
# | 2025     | -121.0 至 86.0           | -25.0 至 17.4        | 中国国际金融| 优于大市 | 55.0           |
# | 2025     | 51.96                    | 11.0                 | 海通       | 优于大市 | 90.84          |
# | 2025     | 13.0                     | 1.0                  | 交银国际   | 买入     | 64.0           |
# | 2025     | 86.0                     | 17.4                 | 大和       | 买入     | 58.0           |
# | 2025     | -3.0                     | -1.0                 | 中信证券   | 买入     | 57.0           |
# | 2026     | 260.0 至 547.0           | 51.0 至 113.8        | 交银国际   | --       | --             |
# | 2026     | 277.74                   | 56.0                 | 海通       | --       | --             |
# | 2027     | 519.0 至 1084.0          | 103.0 至 232.6       | 大和       | --       | --             |
#
# **结论性判断**：
# - **趋势**：短期承压（2025年部分预测亏损），但中长期增长确定性强（2026-2027年纯利CAGR超100%），受益于AI行业红利。
# - **机会**：轻资产模式（资产负债率21.39%）支持灵活扩张；政策驱动数字经济，潜在市场空间扩大。
# - **风险**：行业竞争白热化（52家企业同质化竞争）；盈利滞后可能影响融资能力。
#
# 综上，4Paradigm以研发驱动市场扩张，战略规划清晰，有望在2026年后实现盈利反转，投资者需关注短期波动与生态合作进展。
#
#
# --------------------开始处理任务 9: 提出投资建议，包括目标价、投资评级（买入、持有、卖出等）及依据   --------------------
#
# 最相关的数据块编号: ['16', '17', '6', '10', '11', '14']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 投资建议
#
# 基于对4Paradigm（06682.HK）的财务表现、业务前景及行业定位的综合分析，本报告提出以下投资建议：
#
# #### 投资评级：**买入**
# **目标价：65.0港元**
# （注：目标价基于主要证券商预测值的中位数，范围55.0–90.84港元；当前股价需参考实时市场数据。）
#
# #### 依据分析
# **1. 证券商一致看好盈利改善趋势**
# 主要证券商对2025年盈利预测虽存在分歧（部分预测亏损，部分预测盈利），但均给予“买入”或“优于大市”评级，目标价集中于55.0–90.84港元区间。2026年盈利预测显著转正，显示亏损收窄趋势明确。证券商评级及目标价汇总如下：
#
# | 证券商       | 评级       | 目标价（港元） | 更新日期     |
# |--------------|------------|----------------|--------------|
# | 海通         | 优于大市   | 90.84          | 2025-06-17   |
# | 交银国际     | 买入       | 64.0           | 2025-05-22   |
# | 大和         | 买入       | 58.0           | 2025-06-19   |
# | 中信证券     | 买入       | 57.0           | 2025-05-19   |
# | 中国国际金融 | 优于大市   | 55.0           | 2025-04-01   |
#
# **数据来源：盈利预测概览表。目标价中位数65.0港元反映市场对长期价值的共识。**
#
# **2. 核心业务高速增长驱动业绩改善**
# - **收入与毛利稳健提升**：2024年总收入达52.61亿元（人民币，下同），同比增长25.1%；毛利润22.45亿元，毛利率42.7%，体现较强的定价能力。
# - **亏损持续收窄**：2024年归属母公司亏损2.69亿元，同比减亏70.4%；经调整净亏损2.92亿元，减亏29.6%。自2021年起连续4年减亏，为2025–2026年盈利转正奠定基础。
# - **核心平台爆发式增长**：先知AI平台收入36.76亿元（占比69.9%），同比增长46.7%。IDC数据显示公司连续六年位居中国机器学习平台市场份额第一，技术壁垒巩固行业领导地位。
#
# **3. 创新产品布局打开增量空间**
# - **AI agent与垂直世界模型融合**：公司发布“先知AI平台5.0”，整合GPU资源池化、AI agent全流程管理能力，已落地金融、能源、医疗等10余行业，标杆用户数同比增长16%。
# - **端侧AI与一体机解决方案**：2025年推出SageOne IA（华为合作）和ModelHub AIoT，支持离线部署与隐私保护。端侧AI市场预计2025年进入爆发期，公司技术适配DeepSeek等开源模型，有望抢占企业级AI落地“最后一公里”。
# - **研发投入保障竞争力**：2024年研发费用21.70亿元（费用率41.2%），重点投向生成式AI工具（如AIGS Builder），提升软件开发效率。
#
# **4. 行业对比凸显估值修复潜力**
# 在资讯科技业-软件服务-数码解决方案服务板块（共52家）中，公司关键指标优于同业中位水平：
# - **资产负债率33.17%**：低于行业中位数42.15%，财务结构稳健。
# - **市净率4.82倍**：高于行业中位数1.45倍，反映市场对其技术资产的溢价认可。
# - **收入增速25.1%**：显著高于板块中位数（约10%），成长性突出。
#
# **5. 主要风险提示**
# - **盈利波动风险**：2025年证券商盈利预测分歧较大（纯利区间-121.0至86.0百万元），高研发投入（费用率41.2%）可能延迟盈利兑现。
# - **市场竞争加剧**：AI大模型厂商（如DeepSeek）加速渗透企业市场，可能挤压定价空间。
# - **端侧AI落地不确定性**：2025年若技术迭代不及预期，ModelHub AIoT等新品收入贡献或低于预估。
#
# #### 结论
# 4Paradigm凭借先知AI平台的强劲增长、亏损持续收窄趋势及端侧AI的先发布局，已进入盈利改善通道。结合证券商目标价中位数及行业成长性，给予“买入”评级，目标价65.0港元。建议投资者关注2025年Q3盈利拐点验证及新品落地进展，以把握估值修复机会。
#
#
# --------------------开始处理任务 10: 总结潜在风险因素，包括市场风险、经营风险、政策风险等，并给出风险提示 --------------------
#
# 最相关的数据块编号: ['3', '4', '5', '12', '14', '16']
#
#
# --------------------子任务解决方案--------------------
#
# Subtask solution:
#  ### 潜在风险因素与风险提示
#
# #### 一、市场风险
# 1. **行业竞争加剧**
#    公司所属的数码解决方案服务行业（港股52家同业）呈现高度分化格局。2024年中报显示，行业超60%企业处于亏损状态（如商汤-W、地平线机器人-W亏损均超26亿元），第四范式虽以21.39%的资产负债率低于行业均值（约50%），但税后利润为-1.81亿港元，主营利润率-8.85%，反映行业整体盈利承压。腾讯控股（00700.HK）等巨头在规模与技术生态上形成壁垒，加剧了中小企业生存压力。
#
# 2. **股价波动性高**
#    近半年股价呈现剧烈震荡（见下表），2025年2月单月振幅达42.32%，6月虽上涨19.4%，但成交量与换手率显著放大（6月换手率42.74%），显示市场情绪敏感度高，易受短期因素扰动。
#
# | 日期       | 收盘价(港元) | 月涨跌幅(%) | 振幅(%) | 换手率(%) |
# |------------|--------------|-------------|---------|-----------|
# | 2025-02-28 | 43.0         | -14.17      | 42.32   | 102.15    |
# | 2025-04-30 | 40.55        | -10.88      | 33.30   | 31.80     |
# | 2025-06-30 | 51.40        | +19.40      | 32.64   | 42.74     |
#
# #### 二、经营风险
# 1. **持续亏损与现金流压力**
#    2024年中报显示公司税后利润为-1.81亿港元，每股收益-0.35港元，每股经营性现金流-0.92港元。尽管技术领先（如自动机器学习算法打破世界纪录），但研发与市场拓展投入导致短期难以盈利。对比行业龙头腾讯控股（主营利润率32.89%），公司盈利模式仍需验证规模化落地能力。
#
# 2. **客户集中与项目周期风险**
#    人工智能解决方案依赖大企业客户，项目周期长、定制化程度高，可能导致收入确认延迟。2024年中报营收19.98亿港元，但销售成本占比达57.66%（11.52亿港元），反映项目执行成本控制压力。
#
# #### 三、政策与合规风险
# 1. **数据安全监管趋严**
#    公司业务涉及企业核心数据决策，需符合《网络安全法》《数据安全法》等法规。政策变动可能增加合规成本，例如数据跨境传输限制或算法透明度要求。
#
# 2. **行业补贴政策变动**
#    人工智能行业长期依赖政府补贴与税收优惠。若政策支持力度减弱，将直接影响研发投入与盈利改善进度。
#
# #### 四、技术迭代与人才风险
# 1. **技术更新速度**
#    据灼识咨询报告，公司虽在自动机器学习领域领先，但AI行业技术迭代迅猛（如生成式AI冲击传统决策模型），需持续投入研发以维持竞争力。
#
# 2. **核心人才流失**
#    高端AI人才竞争白热化，同业如商汤-W、创新奇智等均在争夺有限人才资源，人力成本攀升可能加剧亏损。
#
# ---
#
# ### 风险提示总结
# | 风险类别   | 主要表现                                                                 | 潜在影响                                                                 |
# |------------|--------------------------------------------------------------------------|--------------------------------------------------------------------------|
# | **市场风险** | 行业竞争加剧、股价高波动、同业普遍亏损                                   | 估值承压，融资难度增加                                                   |
# | **经营风险** | 持续亏损（中报净亏1.81亿）、现金流紧张（每股现金流-0.92港元）、成本高企 | 短期盈利无改善迹象，依赖外部融资生存                                     |
# | **政策风险** | 数据合规成本上升、补贴政策不确定性                                       | 利润率进一步压缩，技术落地速度放缓                                       |
# | **技术风险** | 迭代加速、人才争夺激烈                                                   | 技术优势被削弱，研发效率下降                                             |
#
# > **结论性判断**：第四范式虽占据细分市场龙头地位且技术领先，但**短期盈利困境与行业竞争白热化构成核心风险**。股价高波动反映市场对扭亏时点分歧巨大（券商2025年盈利预测横跨-121亿至+86亿港元），投资者需警惕现金流压力及政策合规成本上升对估值的持续压制。长期竞争力取决于技术商业化进度与成本控制能力，建议密切跟踪季度亏损收窄趋势及行业政策动向。

# %% [markdown]
# ## 4.3 子任务归入章节

# %%
# 把任务解决方案写入到报告中，形成一篇内容翔实的报告

auto_organize_sections_prompt_template = """
你是一个专业的金融研究报告编辑，需要将以下多个子话题的内容归类到标准的金融研究报告结构中。

每个子话题如下：
-----
{task_content_pairs}
-----

请将这些子任务内容归类到以下标准章节中：
1. 公司概况
2. 业务与行业分析
3. 财务分析
4. 财务建模与预测
5. 公司治理与战略分析
6. 投资价值分析与建议

请输出一个结构化结果，格式如下：
#1# 子任务标题
归类章节：公司概况
内容摘要：该部分内容主要介绍了公司基本信息和股权结构。

#2# 子任务标题
归类章节：财务分析
内容摘要：该部分内容主要分析了三大会计报表和财务比率。

...

要求：
- 不要遗漏任何子任务；
- 不要添加解释或说明；
- 严格按照输出格式；
- 章节名称必须从上面6个中选择；
- 内容摘要要简明扼要。
"""

# 生成子任务标题 + 内容的拼接字符串
task_content_pairs_str = ""
for idx, (task, content) in enumerate(zip(task_list, task_solution_list), 1):
    task_content_pairs_str += f"#{idx}# {task}\n"

# 构建 Prompt
organize_prompt = auto_organize_sections_prompt_template.format(
    task_content_pairs=task_content_pairs_str.strip()
)

# 调用模型
response = base_model.invoke(organize_prompt,enable_thinking=False)
sleep(1)
organize_result = response.content.strip()


# """

# %%
# 归入结果提取
from collections import defaultdict
import re

# 正则提取归类结果
pattern = r'#(\d+)# (.*?)\n归类章节：(.*?)\n内容摘要：(.*?)(?=\n#|\Z)'
matches = re.findall(pattern, organize_result, re.DOTALL)

# 标准章节列表
standard_sections = [
    "公司概况",
    "业务与行业分析",
    "财务分析",
    "财务建模与预测",
    "公司治理与战略分析",
    "投资价值分析与建议"
]

# 构建结构化归类字典
section_content_map = defaultdict(list)

# matches 是你提供的模型输出结果
for idx, task_title, model_section, summary in matches:
    # 清洗模型输出的章节名（去除前后空格/换行）
    cleaned_section = model_section.strip()

    # 初始化匹配章节为 None
    matched_section = None

    # 模糊匹配标准章节
    for std_sec in standard_sections:
        if std_sec in cleaned_section or cleaned_section in std_sec:
            matched_section = std_sec
            break

    # 如果完全没匹配上，归类为 "其他分析"
    if not matched_section:
        matched_section = "其他分析"

    # 清洗任务标题（去除前后空格）
    cleaned_task_title = task_title.strip()

    # 找到对应的完整内容
    full_content = None
    for task, content in zip(task_list, task_solution_list):
        if cleaned_task_title in task or task in cleaned_task_title:
            full_content = content.strip()
            break

    if full_content:
        section_content_map[matched_section].append(idx)

section_content_map
# Out:
# defaultdict(list,
#             {'公司概况': ['1'],
#              '财务分析': ['2', '4'],
#              '业务与行业分析': ['3', '5'],
#              '财务建模与预测': ['6'],
#              '公司治理与战略分析': ['7', '8'],
#              '投资价值分析与建议': ['9', '10']})

# %% [markdown]
# ## 4.4 粗糙的研究报告拼接生成

# %%
full_report = f"# {input_stock_code} 金融研究报告\n\n"

seen_content = set()

# 按照标准章节顺序拼接
for section_title in standard_sections:
    idx = section_content_map.get(section_title)
    # 获取对应章节的内容
    contents = []
    if idx:
        for num in idx:
            # 注意这里的i是字符串，需要转换为整数
            task_index = int(num) - 1  # 索引从0开始
            if task_index < len(task_solution_list):
                content = task_solution_list[task_index].strip()
                if content:  # 如果内容不为空
                    contents.append(content)
    if contents:
        full_report += f"## {section_title}\n\n"
        for content in contents:
            clean_content = re.sub(r'\s+', ' ', content).strip()
            if clean_content not in seen_content:
                full_report += content + "\n\n"
                seen_content.add(clean_content)

# 保存为 Markdown 文件
with open("company_report_final.md", "w", encoding="utf-8") as f:
    f.write(full_report)

print("✅ company_report_final.md")
# Out:
# ✅ company_report_final.md

# %% [markdown]
# ## 3.5 每章单独润色

# %%
# 对每个章节的内容进行润色，一方面是围绕主题来写，纠正幻觉
polish_section_prompt_template = """
你是一个专业的金融研究报告编辑，负责对本章节内容进行润色与整合，目标是输出一个**逻辑清晰、语言专业、无幻觉**的完整章节内容，以markdown文本格式输出。

【报告主题】
-----
{query}
-----

【完整报告目录结构】
-----
{report_structure}
-----

【当前章节标题】
-----
{section_title}
-----

【当前章节的原始内容】
-----
{section_content}
-----

【润色要求】
1. **围绕当前章节标题**组织内容，确保内容紧扣主题；
2. **整理好排版，输出内容应包含当前章节标题**
3. **去掉原始内容中多余的空格、换行符和格式混乱的部分**；
4. **对于原始内容中的表格**，如果有并且是完整的，请使用Markdown格式输出，确保表格内容清晰、易读；
5. **理清本章节在整体报告中的逻辑定位**，整合原始内容，删除冗余信息，合并重复内容，不遗漏重要信息和表述；
6. **确保语言正式、专业**，符合金融研究报告的写作规范；
7. **纠正可能存在的数据错误、逻辑矛盾或幻觉内容**；
8. **仅基于原始内容进行润色，不添加任何原始内容中没有的信息或数据**；
9. **输出格式为完整的markdown格式的研究报告章节**，不要包含解释性语句（如“我将如何整合”）；

特别的，对于当前章节的标题和子标题、列表等，你需要尤其注意格式：
1. 当前章节标题{section_title}为一级标题（#）格式，例如"# 一、"和"# 二、"
2. 其他的子标题不允许使用"# 一、"和"# 二、"这样的中文序号标题格式，可以使用"(一)"或者"(二)"这样的格式，或者使用"1."、"2."这样的数字序号格式等等
2. 对于原始内容进行排版，如果原始内容里面出现了某个子标题内容特别长，需要对其进行浓缩符合子标题风格

请直接输出润色后的章节内容：
"""

section_idx_title =[
    "一、公司概况",
    "二、业务与行业分析",
    "三、财务分析",
    "四、财务建模与预测",
    "五、公司治理与战略分析",
    "六、投资价值分析与建议"
]


polished_result_list = []
# 按照标准章节顺序拼接
for i in range(len(standard_sections)):
    section_title = standard_sections[i]  # 当前章节标题
    print(f"正在润色章节：{section_idx_title[i]}")
    idx = section_content_map.get(section_title)
    # 获取对应章节的内容
    contents = []
    if idx:
        for num in idx:
            # 注意这里的i是字符串，需要转换为整数
            task_index = int(num) - 1  # 索引从0开始
            if task_index < len(task_solution_list):
                content = task_solution_list[task_index].strip()
                if content:  # 如果内容不为空
                    contents.append(content)
    if contents:
        polish_section_prompt = polish_section_prompt_template.format(
            query=task1,  # 输入的研究任务
            report_structure='\n'.join(section_idx_title),  # 报告结构
            section_title=section_idx_title[i],  # 当前章节标题
            section_content='\n\n'.join(contents)  # 当前章节内容
        )
        # 调用模型进行润色
        polish_response = deepseek_r1.invoke(polish_section_prompt)
        sleep(2)
        polished_content = polish_response.content.strip()
        polished_result_list.append(polished_content)  # 存储润色后的内容

# pickle保存润色后的内容
import pickle
with open('comany_polished_result_list.pkl', 'wb') as f:
    pickle.dump(polished_result_list, f)
# Out:
# 正在润色章节：一、公司概况
# 正在润色章节：二、业务与行业分析
# 正在润色章节：三、财务分析
# 正在润色章节：四、财务建模与预测
# 正在润色章节：五、公司治理与战略分析
# 正在润色章节：六、投资价值分析与建议

# %% [markdown]
# ## 3.6 输出markdown格式的报告（之前的是文本格式）

# %%
# 可以支持把llm生成结果保存为markdown的函数
import os
import pandas as pd

writer_data_value = {}
writer_data_desc = {}

class MarkdownReportBuilder:
    def __init__(self, report_title="调研报告", output_path="comany_report.md", stream_out_path = "company_report_stream_output.md", image_dir="./company_img/"):
        self.title = report_title
        self.content = []
        self.current_content = ""  # 保存当前写了的临时的结果
        self.image_counter = 0
        self.table_couneter = 0
        self.image_dir = image_dir
        self.output_path = output_path
        self.stream_out_path = stream_out_path
        
        # 创建图片目录（如果不存在）
        if not os.path.exists(self.image_dir):
            os.makedirs(self.image_dir)
    # 实时输出到文件    
    def stream_output(self, text):
        """实时输出到文件"""
        with open(self.stream_out_path, "a", encoding="utf-8") as f:
            f.write(text + "\n")

    def add_paragraph(self, text):
        """添加一段文字"""
        self.content.append(f"{text}\n")
        self.current_content += f"{text}\n"
        self.stream_output(f"{text}\n")

    def add_table(self, df: pd.DataFrame, caption=None):
        """添加一个 DataFrame 表格"""
        if caption:
            self.content.append(f"**{caption}**\n")
            self.current_content += f"**{caption}**\n"
            self.stream_output(f"**{caption}**\n")
            
        self.content.append(df.to_markdown(index=False) + "\n")
        self.current_content += df.to_markdown(index=False) + "\n"
        self.stream_output(df.to_markdown(index=False) + "\n")
        self.table_couneter += 1

    def add_image(self, image_path, caption=""):
        """添加一张图片（将原图复制到指定目录）"""
        import shutil
        new_image_name = f"image_{self.image_counter}{os.path.splitext(image_path)[-1]}"
        new_image_path = os.path.join(self.image_dir, new_image_name)
        shutil.copyfile(image_path, new_image_path)
        self.content.append(f"![{caption}]({new_image_path})\n")
        self.current_content += f"![{caption}]({new_image_path})\n"
        self.stream_output(f"![{caption}]({new_image_path})\n")
        self.image_counter += 1

    def save(self):
        """保存报告为 Markdown 文件"""
        with open(self.output_path, "w", encoding="utf-8") as f:
            f.write(f"---\ntitle: 公司研报-{company_name}\n---\n\n")
            f.write("\n".join(self.content))
        print(f"报告已保存至：{self.output_path}")
        
    def clear_current_content(self):
        """清空当前内容"""
        self.current_content = ""
    
    def get_current_content(self):
        """获取当前内容"""
        return self.current_content


# 全局报告对象（适用于单次任务）
report_builder = MarkdownReportBuilder(report_title="公司研报"+ " - " + input_stock_code, output_path="company_report.md", image_dir="./company_img/")

@tool
def add_plain_text(content: str):
    """
    添加一段文字内容到报告中，除了图片和表格，其他内容都必须调用这个函数才能添加到报告中。
    """
    report_builder.add_paragraph(content)
    return "已添加该段文字"

@tool
def add_table(df_key_name: str, caption: str = None):
    """把调用plain_text_dataframe_to_table函数生成的DataFrame添加到报告中
    Args:
        df_key_name (str): writer_data_value里面指向DataFrame的键名
        caption (str): 表格的编号
    """
    if df_key_name not in writer_data_value:
        return f"没有找到键名为 '{df_key_name}' 的DataFrame，请先调用plain_text_dataframe_to_table函数生成表格数据。检查表格数据是否成功生成保存！"
    df = writer_data_value[df_key_name]
    report_builder.add_table(df,caption)
    table_idx = report_builder.table_couneter
    return "已添加该表格，该表的编号为 表{}".format(table_idx)

@tool
def add_image(image_path: str, caption: str = None):
    """把调用draw_data_date_one_list_line_plot等画图函数生成的图片添加到报告中
    Args:
        image_path (str): 已经画好图的图片的存储路径
        caption (str): 图片的标题或说明文字
    """
    report_builder.add_image(image_path, caption)
    img_idx = report_builder.image_counter
    return "已添加该图片，该图片的编号为 图片{}".format(img_idx)

@tool
def save_report(output_path: str = "company_report.md"):
    """保存报告为markdown文件"""
    report_builder.save()
    return f"报告已保存至文件： {output_path}"

# 输入为dict的形式，变成一个dataframe，存在collected_data_value中，键名为df_key_name
# 例如{
# "H":['a','b','c,'d']
# "a":[1,2,3,4],
# "b":[5,6,7,8],}
@tool
def plain_text_dataframe_to_table(
    df_key_name: str,
    data_dict: dict
):
    """
    将报告中文本格式的表格转化为dataframe，输入需要把表格的数据以字典形式传入，最后会把数据保存到writer_data_value中，保存的key为指定的参数df_key_name，供后续调用add_table函数插入到报告中。
    Args:
        df_key_name (str): 保存DataFrame的键名，不要和已有的键名冲突，可以取为插入文档中表格的名字
        data_dict (dict): 包含数据的字典，键为列名，值为列数据列表

    Returns:
        str: 返回保存成功的信息
    """
    global writer_data_value, writer_data_desc, report_builder
    try:
        df = pd.DataFrame(data_dict)
    except Exception as e:
        return f"数据转换为DataFrame失败: {str(e)}，请注意数据格式是否正确"
    writer_data_value[df_key_name] = df
    writer_data_desc[df_key_name] = f"写作时需要使用的数据表，键名为{df_key_name}"
    return f"DataFrame已保存到writer_data_value中，键名 '{df_key_name}' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表{report_builder.table_couneter + 1}。"

# # 画图函数
# 支持输入数据列表y_list，日期列表date_list，画出来，保存为图片，返回图片保存路径
@tool
def draw_data_date_one_list_line_plot(
    y_list, 
    date_list,
    title="数据变化趋势", 
    xlabel="日期", 
    ylabel="数值", 
    legend_label="数据", 
    image_path="data_trend.jpg") -> str:
    """
    绘制一维简单数据变化趋势折线图，支持输入单个的数据列表和日期列表，要求数据列表和日期列表长度一致，按照日期顺序排序
    Args:
        y_list (List[float]): 数据列表
        date_list (List[str]): 日期列表，格式为"YYYY-MM-DD"
        title (str): 图表标题
        xlabel (str): x轴标签
        ylabel (str): y轴标签
        legend_label (str): 图例标签
    returns:
        str: 图片保存路径
    """
    from matplotlib import pyplot as plt
    import os

    # 检查输入数据长度是否一致
    if len(y_list) != len(date_list):
        return ("数据列表和日期列表长度不一致")

    # 转换日期字符串为日期对象
    try:
        date_list = [datetime.strptime(date, "%Y-%m-%d") for date in date_list]
    except ValueError:
        return ("日期格式错误，请使用YYYY-MM-DD格式的日期字符串")

    # 绘图
    plt.figure(figsize=(10, 5))
    plt.plot(date_list, y_list, marker='o', label=legend_label)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    plt.legend()
    
    # 保存图片
    # image_path = "data_trend.jpg"
    plt.tight_layout()
    plt.savefig(image_path)
    plt.close()

    return "图片保存路径为: " + image_path + "，稍后可以通过调用add_image函数将图片插入到报告中"

# 绘制一维的数据占比图
@tool
def draw_data_one_list_pie_chart(y_list, labels, title="数据占比图", image_path="data_pie_chart.jpg") -> str:
    """
    绘制一维数据占比饼图，支持输入单个的数据列表和标签列表，要求数据列表和标签列表长度一致
    Args:
        y_list (List[float]): 数据列表，饼图的每一块对应一个数据值，需要保证所有数据非负
        labels (List[str]): 标签列表
        title (str): 图表标题
        image_path (str): 图片保存路径
    """
    from matplotlib import pyplot as plt

    # 检查输入数据长度是否一致
    if len(y_list) != len(labels):
        return ("数据列表和标签列表长度不一致")
    # 检查数据是否为非负数
    if any(value < 0 for value in y_list):
        return ("数据列表中的值必须为非负数，请检查数据输入，该数据不适合用饼图展示，请尝试使用条形图draw_data_one_list_bar_chart或者折线图draw_data_date_one_list_line_plot")

    # 绘图
    plt.figure(figsize=(8, 8))
    plt.pie(y_list, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title(title)
    
    # 保存图片
    plt.tight_layout()
    plt.savefig(image_path)
    plt.close()

    return "图片保存路径为: " + image_path + "，稍后可以通过调用add_image函数将图片插入到报告中"

# 绘制一维数据的条形图，例如用于展示行业地位，要求能支持将其中某一个柱子的颜色突出
@tool
def draw_data_one_list_bar_chart(y_list, labels, highlight_index=None, title="数据条形图", xlabel="类别", ylabel="数值", image_path="data_bar_chart.jpg") -> str:
    """
    绘制一维数据条形图，支持输入单个的数据列表和标签列表，要求数据列表和标签列表长度一致
    Args:
        y_list (List[float]): 数据列表
        labels (List[str]): 标签列表
        highlight_index (Optional[int]): 突出显示的柱子索引，默认为None表示不突出显示
        title (str): 图表标题
        xlabel (str): x轴标签
        ylabel (str): y轴标签
        image_path (str): 图片保存路径
    """
    from matplotlib import pyplot as plt

    # 检查输入数据长度是否一致
    if len(y_list) != len(labels):
        raise ValueError("数据列表和标签列表长度不一致")

    # 绘图
    plt.figure(figsize=(10, 5))
    bars = plt.bar(labels, y_list, color='blue')

    # 突出显示指定柱子
    if highlight_index is not None and 0 <= highlight_index < len(bars):
        bars[highlight_index].set_color('red')

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    # 保存图片
    plt.tight_layout()
    plt.savefig(image_path)
    plt.close()

    return "图片保存路径为: " + image_path + "，稍后可以通过调用add_image函数将图片插入到报告中"


markdown_tools = [
    add_plain_text,
    add_table,
    add_image,
    save_report,
    plain_text_dataframe_to_table,
    draw_data_date_one_list_line_plot,
    draw_data_one_list_pie_chart,
    draw_data_one_list_bar_chart
]

markdown_agent = tool_agent.bind_tools(markdown_tools)
markdown_format_prompt_template = """
你是一个专业的金融研究报告编辑助手，负责将原始文稿内容结构化地写入 Markdown 格式的调研报告中。

你的任务是：
1. 分析【章节内容】，识别出需要结构化处理的内容（如表格、图表、普通文本等）；
2. 按照以下规则调用工具函数，将内容写入报告；
3. 最终使用 `save_report` 保存报告。

【调用工具的规则】：

- **遇到表格内容**（如：`|列1|列2|\n|---|---|`）时：
  1. 使用 `plain_text_dataframe_to_table` 将其转换为 DataFrame；
  2. 使用 `add_table` 将表格插入报告；
  3. 在输出内容中不再保留原始文本格式表格。

- **遇到图表描述**（如“收入趋势”、“行业占比”、“柱状图”等）时：
  1. 使用对应的绘图工具（如 `draw_data_date_one_list_line_plot` 或 `draw_data_one_list_pie_chart`）生成图片；
  2. 使用 `add_image` 将图片插入报告；

- **遇到普通文本内容**（非表格、非图表）时：
  1. 使用 `add_plain_text` 添加内容，保证内容中没有转义字符或unicode值；
  2. 保持段落结构清晰，不遗漏关键信息。

- **完成内容输出后**：
  1. 使用 `save_report` 保存最终的 Markdown 报告。

【注意事项】：
- 你的下游就是研究报告，千万一定不要对中文进行转义，add_plain_text的参数不要出现转义字符或者unicode值；
- 你不能对原始内容进行任何润色、改写、缩写或扩展；
- 你不能添加任何你自己的解释、评价、分析、总结或者你的思维过程；
- 你不能修改原文稿中的任何数据、格式或语序，除非是识别到文本格式的表格需要调用表格处理函数输出，不保留原始的文本形式表格内容；
- 所有文本内容必须原样通过 `add_plain_text` 添加到报告中；
- 表格内容必须先调用 `plain_text_dataframe_to_table` 再调用 `add_table`添加;
- 要增加图表，必须先调用绘图函数生成图片，再调用 `add_image` 添加到报告中。

原始文稿的章节标题为：
-----
{section_title}
-----

原始文稿的章节内容为：
-----
{section_content}
-----

请开始调用工具，将内容结构化写入报告。
"""

# %%
# for polist list
for i in range(len(polished_result_list)):
    polished_content = polished_result_list[i]
    section_title = section_idx_title[i]  # 当前章节标题
    print(f"\n\n--------------------开始处理章节 {i+1}: {section_title} --------------------\n")
    writer_history_message = []
    while True:
        # 构建章节写作提示
        markdown_format_prompt = markdown_format_prompt_template.format(
            section_title=section_title,  # 当前章节标题
            section_content=polished_content  # 当前章节内容
        )
        # 调用markdown写作助手
        writer_history_message.append(HumanMessage(
            content=markdown_format_prompt  # 当前章节内容
        ))
        markdown_writer_output_response = markdown_agent.invoke(writer_history_message,enable_thinking=False) # 输出到markdown中
        sleep(1)  # 等待1秒，避免过快调用
        writer_history_message.append(markdown_writer_output_response)
        if markdown_writer_output_response.tool_calls is None or len(markdown_writer_output_response.tool_calls) == 0:
            break
        # 执行markdown输出工具
        for tool_call in markdown_writer_output_response.tool_calls:
            tool_name = tool_call['name']
            tool_args = tool_call['args']
            selected_tool = globals()[tool_call["name"]]
            current_data = selected_tool.invoke(tool_args)  # 正确调用方式
            if tool_name == "save_report":
                break
            writer_history_message.append(ToolMessage(
                        content=str(current_data),  # 转为字符串
                        name=tool_name,  # 工具名称
                        tool_call_id=tool_call['id']  # 匹配对应的 tool_call ID
            ))
            write_print_to_log(f"调用工具 {tool_name}, 参数: {tool_args}, 返回结果: {current_data}")
            with open(trace_log, 'a', encoding='utf-8') as f:
                f.write(f"调用工具 {tool_name}, 参数: {tool_args}, 返回结果: {current_data}\n")
        if tool_name == "save_report":
            break
        
# 手动调用save_report
report_builder.save()
# Out:
# --------------------开始处理章节 1: 一、公司概况 --------------------
#
# 调用工具 add_plain_text, 参数: {'content': '# 一、公司概况'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '## 1. 公司基本信息\n**4Paradigm（第四范式，股票代码：06682.HK）** 是中国领先的人工智能技术企业，专注于企业级AI平台的研发与应用。公司于2023年9月28日在香港联合交易所主板上市。核心信息如下：'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'company_basic_info', 'data_dict': {'项目': ['公司全称', '英文名称', '上市时间', '交易所', '股票代码', '所属行业', '主营业务'], '内容': ['北京第四范式智能技术股份有限公司', 'Beijing Fourth Paradigm Technology Co., Ltd.', '2023年9月28日', '香港联合交易所（HKEX）', '06682.HK', '资讯科技业 - 软件服务 - 数码解决方案服务', '销售自主研发的AI平台（"先知平台"）及即用型产品，并提供应用开发等服务，覆盖中国及海外市场']}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'company_basic_info' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表1。
# 调用工具 add_table, 参数: {'caption': '表1', 'df_key_name': 'company_basic_info'}, 返回结果: 已添加该表格，该表的编号为 表1
# 调用工具 add_plain_text, 参数: {'content': '## 2. 财务与股价表现'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '### 2.1 关键财务结构趋势（2018-2024年）\n基于资产负债表数据，公司财务结构演变如下：'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'financial_structure_trend', 'data_dict': {'报告日期': ['2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31', '2024-12-31'], '总资产(港元)': ['981,107,000', '2,028,908,000', '3,199,008,000', '6,696,697,000', '8,179,995,000', '7,147,274,000', '7,587,645,000'], '总负债(港元)': ['713,647,000', '1,376,375,000', '2,016,009,000', '6,448,684,000', '6,718,984,000', '5,504,124,000', '5,090,140,000'], '净资产(港元)': ['-267,460,000', '-652,533,000', '-1,182,999,000', '-248,013,000', '-1,461,011,000', '5,452,514,000', '5,070,888,000'], '流动比率<sup>①</sup>': ['0.86', '0.86', '1.03', '0.90', '0.95', '1.03', '1.12'], '资产负债率(%)': ['72.75%', '67.84%', '63.02%', '96.30%', '82.13%', '77.01%', '67.05%']}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'financial_structure_trend' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表2。
# 调用工具 add_table, 参数: {'caption': '表2', 'df_key_name': 'financial_structure_trend'}, 返回结果: 已添加该表格，该表的编号为 表2
# 调用工具 add_plain_text, 参数: {'content': '> *注①：流动比率 = 流动资产合计 / 流动负债合计*\n\n**财务分析**：\n- **净资产由负转正**：2023年净资产跃升至54.53亿港元，标志公司进入盈利积累阶段。\n- **偿债能力优化**：流动比率从2018年的0.86提升至2024年的1.12，短期流动性压力显著缓解。\n- **杠杆率下降**：资产负债率从2021年的96.30%降至2024年的67.05%，财务结构趋于稳健。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '### 2.2 近期股价表现（2025年1月-6月）\n股价波动显著，反映市场对AI行业的关注度与风险偏好变化：'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'stock_price_performance', 'data_dict': {'日期': ['2025-01-28', '2025-02-28', '2025-03-31', '2025-04-30', '2025-05-30', '2025-06-30'], '开盘价(港元)': ['50.95', '50.10', '43.75', '47.65', '40.55', '43.00'], '收盘价(港元)': ['50.10', '43.00', '45.50', '40.55', '43.05', '51.40'], '最高价(港元)': ['52.85', '63.00', '54.60', '48.65', '49.55', '54.95'], '最低价(港元)': ['38.50', '41.80', '42.05', '33.50', '38.50', '40.90'], '成交量(股)': ['125,965,169', '301,054,578', '137,503,599', '93,628,562', '101,748,950', '125,840,828'], '成交额(港元)': ['5,522,599,330', '16,300,643,808', '6,650,743,836', '3,687,792,976', '4,434,794,726', '6,126,044,570'], '涨跌幅(%)': ['-1.67', '-14.17', '+5.81', '-10.88', '+6.17', '+19.40'], '振幅(%)': ['28.16', '42.32', '29.19', '33.30', '27.25', '32.64']}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'stock_price_performance' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表3。
# 调用工具 add_table, 参数: {'caption': '表3', 'df_key_name': 'stock_price_performance'}, 返回结果: 已添加该表格，该表的编号为 表3
# 调用工具 add_plain_text, 参数: {'content': '**股价分析**：\n- **高波动性**：单月振幅最高达42.32%（2025年2月），反映行业情绪敏感。\n- **成交活跃**：2025年2月成交量突破3亿股，成交额达163亿港元，显示资金博弈激烈。\n- **复苏迹象**：2025年6月收盘价较5月上涨19.40%，可能受益于政策或业绩预期改善。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '## 3. 结论与风险提示\n- **核心优势**：深耕AI平台化技术（"先知平台"），服务企业智能化转型需求，契合中国数字经济战略方向。\n- **风险关注**：\n  - **市场波动敏感**：股价高波动性反映行业估值分化，需警惕技术商业化不及预期的回调风险。\n  - **研发投入压力**：AI领域技术迭代迅速，持续高研发投入可能影响短期盈利表现。\n- **机会判断**：财务结构改善与净资产转正为长期发展奠定基础，AI渗透率提升有望释放规模效应。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '> 数据来源：公司财务报表及公开市场交易数据（截至2025年6月30日）。'}, 返回结果: 已添加该段文字
# 报告已保存至：company_report.md
#
#
# --------------------开始处理章节 2: 二、业务与行业分析 --------------------
#
# 调用工具 add_plain_text, 参数: {'content': '# 二、业务与行业分析'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '### (一) 公司主营业务\n第四范式（06682.HK）专注于人工智能驱动的企业级软件服务，核心业务为提供端到端AI解决方案，涵盖决策优化、智能风控及运营效率提升等场景。公司隶属于“资讯科技业—软件服务—数码解决方案服务”细分行业，通过自主研发的AI平台（如Prophet AIOS）赋能金融、零售、制造等垂直领域客户，实现数据驱动的智能化转型。服务模式包括标准化SaaS产品与定制化解决方案，收入主要来源于软件订阅费及项目实施费。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '### (二) 核心竞争力分析\n1. **技术优势**：\n   依托深度学习与AutoML（自动机器学习）等核心技术，构建高壁垒AI平台。系统支持低代码开发，降低企业AI部署门槛，并具备实时数据处理能力（在金融风控等高频场景表现突出）。研发投入持续高位（2024年报销售成本31.97亿港元，占营收57.3%），支撑技术迭代。相较同行，第四范式在算法效率与场景适配性上具备差异化优势（如金融反欺诈模型准确率领先行业平均水准）。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '2. **客户群体与粘性**：\n   客户以大型金融机构和头部企业为主（银行、保险及零售巨头）。2024年年报显示，营业收入55.77亿港元，同比增长显著（较2024年中报19.98亿港元环比提升179%），反映客户需求扩张及复购率提升。高净值客户（金融业）占比超60%，合同周期多为3年期以上，粘性强。行业数据表明，其在金融细分市场渗透率居前。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '3. **财务韧性**：\n   尽管处于战略投入期导致亏损（2024年税后利润-1.81亿港元，主营利润率-5.88%），但资产负债率仅21.39%（2024年中报数据），显著低于行业均值（52家企业中位数为46.58%），显示低杠杆运营和稳健资产结构。流动资产充裕（52.04亿港元），支撑长期研发投入。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '### (三) 行业地位与市场份额\n1. **行业定位**：\n   在“数码解决方案服务”细分赛道（52家企业）中，第四范式属中上游技术驱动型厂商。以资产规模计（70.83亿港元），公司位列行业前30%，落后于腾讯（17707.35亿港元）等巨头，但领先于创新奇智（32.82亿港元）等垂直AI服务商。在AI专项解决方案领域，与商汤（00020.HK）、创新奇智（02121.HK）形成直接竞争，但技术聚焦点差异明显——第四范式强于决策优化，商汤侧重计算机视觉。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '2. **市场份额与竞争格局**：\n   基于2024年财务数据，公司在AI解决方案细分市场份额约5%–8%（估算依据：营收55.77亿港元占行业总营收约1.5%–2.5%，行业头部集中度高）。核心竞争优势包括：\n   - **技术壁垒**：AutoML专利数量行业前三，平台兼容性优于同业。 \n   - **垂直深耕**：金融行业市占率约15%（第三方机构估算），领先多数同行。 \n   - **增长动能**：2024年营收增速超行业平均（行业营收中位数增速约10%，公司全年同比增约30%）。'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'financial_comparison', 'data_dict': {'股票代码': ['06682', '00020', '02121', '06638', '02438', '02495', '00700'], '股票简称': ['第四范式', '商汤-W', '创新奇智', '金融壹账通', '出门问问', '声通科技', '腾讯控股（参考）'], '营收(亿港元)': [19.98, 18.62, 6.12, 15.62, 1.74, 3.97, 3430.45], '毛利率(%)': [42.3, 44.1, 33.8, 36.4, 64.4, 43.6, 52.9], '净利率(%)': [-9.06, -142.3, -32.4, -9.21, -356.5, -158.9, 28.4], '资产负债率(%)': [21.39, 30.25, 31.87, 45.33, 33.43, 135.51, 43.95]}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'financial_comparison' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表4。
# 调用工具 add_table, 参数: {'df_key_name': 'financial_comparison', 'caption': '表4：2024年中报可比公司财务表现对比'}, 返回结果: 已添加该表格，该表的编号为 表4
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'market_position_comparison', 'data_dict': {'维度': ['核心定位', '技术壁垒', '商业化场景'], '第四范式': ['平台为中心的决策类AI领导者', '自动机器学习算法（OGB两项世界纪录保持者）', '跨行业企业级决策优化（金融/零售/制造）'], '主要可比公司差异点': ['商汤-W：侧重视觉AI；金融壹账通：垂直金融场景', '创新奇智：制造业Know-How整合；出门问问：生成式AI', '声通科技：客服交互场景；腾讯：消费端+企业端综合布局']}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'market_position_comparison' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表5。
# 调用工具 add_table, 参数: {'df_key_name': 'market_position_comparison', 'caption': '表5：市场定位与技术能力对比'}, 返回结果: 已添加该表格，该表的编号为 表5
#
#
# --------------------开始处理章节 3: 三、财务分析 --------------------
#
# 调用工具 add_plain_text, 参数: {'content': '# 三、财务分析\n'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'data_dict': {'报告日期': ['2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31', '2024-12-31'], '营业额': ['127,750', '459,518', '942,238', '2,018,399', '3,082,637', '4,204,142', '5,260,650'], '销售成本': ['73,163', '259,437', '512,503', '1,064,924', '1,595,991', '2,224,594', '3,015,821'], '毛利': ['54,587', '200,081', '429,735', '953,475', '1,486,646', '1,979,548', '2,244,829'], '研发费用': ['193,159', '416,418', '565,674', '1,249,485', '1,650,010', '1,768,996', '2,169,767'], '经营溢利': ['-336,027', '-550,943', '-560,066', '-1,172,806', '-1,025,902', '-545,434', '-355,082'], '股东应占溢利': ['-367,960', '-716,576', '-749,650', '-1,785,655', '-1,644,897', '-908,717', '-268,788'], '每股基本盈利（港元）': ['-1.96', '-3.82', '-4.00', '-7.63', '-6.15', '-2.80', '-0.58']}, 'df_key_name': '利润表分析'}, 返回结果: DataFrame已保存到writer_data_value中，键名 '利润表分析' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表6。
# 调用工具 add_table, 参数: {'caption': '表6', 'df_key_name': '利润表分析'}, 返回结果: 已添加该表格，该表的编号为 表6
# 调用工具 plain_text_dataframe_to_table, 参数: {'data_dict': {'报告日期': ['2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31', '2024-12-31'], '经营业务现金净额': ['-197,983', '-311,336', '-365,906', '-580,000', '-549,060', '-402,467', '-221,664'], '投资业务现金净额': ['-328,787', '-357,058', '-592,023', '-3,969,619', '-221,620', '-275,170', '-1,096,169'], '融资业务现金净额': ['545,647', '1,028,766', '969,265', '4,283,540', '-90,140', '930,719', '-30,931'], '期末现金': ['394,658', '703,786', '1,052,073', '1,292,686', '1,326,818', '1,977,891', '858,618']}, 'df_key_name': '现金流量表分析'}, 返回结果: DataFrame已保存到writer_data_value中，键名 '现金流量表分析' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表7。
# 调用工具 add_table, 参数: {'caption': '表7', 'df_key_name': '现金流量表分析'}, 返回结果: 已添加该表格，该表的编号为 表7
# 调用工具 plain_text_dataframe_to_table, 参数: {'data_dict': {'报告日期': ['2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31', '2024-12-31'], '每股净资产（港元）': ['-0.54', '-1.31', '-2.39', '-0.71', '-3.19', '10.84', '10.26'], '每股基本盈利（港元）': ['-1.96', '-3.82', '-4.00', '-7.63', '-6.15', '-2.80', '-0.58'], '股东应占溢利（千港元）': ['-367,960', '-716,576', '-749,650', '-1,785,655', '-1,644,897', '-908,717', '-268,788']}, 'df_key_name': '股东权益分析'}, 返回结果: DataFrame已保存到writer_data_value中，键名 '股东权益分析' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表8。
# 调用工具 add_table, 参数: {'caption': '表8', 'df_key_name': '股东权益分析'}, 返回结果: 已添加该表格，该表的编号为 表8
# 调用工具 plain_text_dataframe_to_table, 参数: {'data_dict': {'指标': ['毛利率', 'ROE', '现金流匹配度', '研发费用率', '净亏损率'], '数值': ['42.7%', '-5.16%', '-1.34x', '41.2%', '-5.1%'], '同比变动': ['-4.4个百分点', '+43.0个百分点', '+0.8x', '-0.9个百分点', '+16.5个百分点']}, 'df_key_name': '核心财务比率'}, 返回结果: DataFrame已保存到writer_data_value中，键名 '核心财务比率' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表9。
# 调用工具 add_table, 参数: {'caption': '表9', 'df_key_name': '核心财务比率'}, 返回结果: 已添加该表格，该表的编号为 表9
# 调用工具 plain_text_dataframe_to_table, 参数: {'data_dict': {'指标': ['毛利率(%)', 'ROE(%)', '净利率(%)', '研发费用率(%)'], '第四范式': ['42.7*', '-5.16*', '-5.1*', '41.2*'], '行业中位数': ['9.3', '-4.75', '-6.2', '未披露'], '行业龙头（腾讯控股）': ['32.9', '10.6', '-', '创新奇智(32.7%)'], '排名/水平': ['第8位（52家）', '中下游', '中等水平', '行业领先']}, 'df_key_name': '同业对比'}, 返回结果: DataFrame已保存到writer_data_value中，键名 '同业对比' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表10。
# 调用工具 add_table, 参数: {'caption': '表10', 'df_key_name': '同业对比'}, 返回结果: 已添加该表格，该表的编号为 表10
# 调用工具 plain_text_dataframe_to_table, 参数: {'data_dict': {'年份': ['2024', '2023', '2022', '2021'], 'ROE(%)': ['-5.16', '-48.15', '170.83*', '233.56*'], '毛利率(%)': ['42.7', '47.1', '48.2', '47.2'], '净利率(%)': ['-5.1', '-21.6', '-53.4', '-88.4'], '研发费用率(%)': ['41.2', '42.1', '53.5', '61.9'], '现金流匹配度(x)': ['-1.34', '-2.14', '-1.78', '-1.76']}, 'df_key_name': '财务比率趋势'}, 返回结果: DataFrame已保存到writer_data_value中，键名 '财务比率趋势' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表11。
# 调用工具 add_table, 参数: {'caption': '表11', 'df_key_name': '财务比率趋势'}, 返回结果: 已添加该表格，该表的编号为 表11
# 调用工具 add_plain_text, 参数: {'content': '## (三) 综合财务评估与风险提示\n\n### 1. 积极信号\n- 营收保持超80%CAGR高增长；  \n- 亏损幅度显著收窄（2024年净亏损率-5.1%）；  \n- 净资产由负转正，技术投入初见成效。\n\n### 2. 核心风险\n1. **流动性压力**：2024年现金储备同比减少56.6%，融资环境恶化可能影响运营；  \n2. **盈利可持续性**：毛利率同比下滑4.4个百分点，规模化盈利路径待验证；  \n3. **投资回报风险**：激进投资活动（2024年流出109.62亿港元）需警惕资产回报不及预期；  \n4. **行业竞争加剧**：毛利率下行反映定价压力，需强化差异化壁垒。\n\n### 3. 财务展望\n技术溢价（毛利率42.7%）与研发壁垒（费用率41.2%）构成核心优势，ROE改善至-5.16%反映经营效率提升。当前需优先保障现金流安全，优化成本结构以加速盈利拐点到来。随着AI Agent平台收入高增长（2024年+46.7%），盈利转正可期。\n'}, 返回结果: 已添加该段文字
# 报告已保存至：company_report.md
#
#
# --------------------开始处理章节 4: 四、财务建模与预测 --------------------
#
# 调用工具 add_plain_text, 参数: {'content': '# 四、财务建模与预测\n\n### 估值模型选择与构建\n鉴于第四范式（06682.HK）尚未实现盈利（2024年归属母公司亏损2.69亿元），传统PE估值法适用性有限。采用**市销率（PS）估值法**为主，辅以**贴现现金流（DCF）模型**进行交叉验证。\n\n#### 1. 市销率（PS）估值\n参考港股软件服务行业（数码解决方案服务）52家可比公司数据，行业平均PS为**19.54倍**（剔除极端值后）。结合公司2024年财务表现：'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '- **营业收入**：52.61亿元（人民币），同比增长25.1%\n- **核心业务增速**：先知AI平台收入36.76亿元（占比69.9%），同比增46.7%'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '**估值计算**：\n合理PS取行业均值19.54倍，则公司合理市值 = 52.61 × 19.54 ≈ **1,027.6亿元**（约1,117亿港元）。该估值隐含对公司持续高增长的预期，需通过DCF模型验证可持续性。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '#### 2. 贴现现金流（DCF）模型\n采用三阶段模型，关键假设如下：\n- **高速增长期（5年）**：营收增速25%（2025–2027年）、20%（2028–2029年）\n- **过渡期（5年）**：增速线性降至永续增长率5%\n- **永续增长率**：5%\n- **利润率改善**：2028年扭亏（营业利润率8%），2030年提升至15%，永续期20%\n- **WACC**：12.4%（股权成本14.75%，债务成本6%，债务占比20%）\n- **自由现金流（FCFF）**：基于营业利润调整资本支出及营运资本变动'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '**估值结果**：\n股权价值约**169.2亿港元**（对应股价36.3港元），反映市场需平衡高增长与盈利不确定性。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '### 关键变量敏感性分析\n#### 1. 毛利率波动影响\n2024年毛利率为42.7%，其变动对净利润敏感度高：'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'data_dict': {'毛利率变动': ['-5%', '-2%', '基准', '+2%', '+5%'], '毛利润（亿元）': [20.33, 21.89, 22.45, 23.01, 24.11], '净利润（亿元）': [-3.79, -3.24, -2.69, -2.14, -1.29], '变动幅度': ['-40.9%', '-20.4%', '0%', '+20.4%', '+52.0%']}, 'df_key_name': '毛利率敏感性分析'}, 返回结果: DataFrame已保存到writer_data_value中，键名 '毛利率敏感性分析' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表12。
# 调用工具 add_table, 参数: {'df_key_name': '毛利率敏感性分析', 'caption': '表：毛利率变动对净利润的敏感性分析（2024年）'}, 返回结果: 已添加该表格，该表的编号为 表12
# 调用工具 add_plain_text, 参数: {'content': '**结论**：\n- 毛利率每下降1%，净利润减少约0.22亿元。主要风险来自**GPU成本上升**（英伟达芯片进口占原材料成本超30%）。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '#### 2. 汇率变动影响\n公司部分采购以美元结算（如GPU进口），人民币兑美元汇率波动影响如下：'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'data_dict': {'人民币贬值幅度': ['-5%', '-2%', '基准', '+2%', '+5%'], '成本增加（亿元）': [0.45, 0.18, 0, -0.18, -0.45], '净利润（亿元）': [-3.14, -2.87, -2.69, -2.51, -2.24], '变动幅度': ['-16.7%', '-6.7%', '0%', '+6.7%', '+16.7%']}, 'df_key_name': '汇率敏感性分析'}, 返回结果: DataFrame已保存到writer_data_value中，键名 '汇率敏感性分析' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表13。
# 调用工具 add_table, 参数: {'df_key_name': '汇率敏感性分析', 'caption': '表：人民币汇率变动对净利润的敏感性分析'}, 返回结果: 已添加该表格，该表的编号为 表13
# 调用工具 add_plain_text, 参数: {'content': '**结论**：\n- 人民币每贬值1%，净利润减少约0.09亿元。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '### 估值结论与风险提示\n1. **估值结论**：\n   PS法（1,117亿港元）反映市场对AI赛道的高增长溢价，DCF法（169亿港元）提示盈利兑现不确定性。当前股价或已部分透支短期预期。\n\n2. **核心风险**：\n   - **技术迭代**：AI行业技术更新迅速，可能侵蚀市场份额  \n   - **政策监管**：数据安全法规趋严限制业务拓展  \n   - **成本控制**：GPU价格波动及汇率风险延缓盈利改善  \n\n3. **投资建议**：\n   短期维持**"持有"**评级，重点关注2025年催化剂：\n   - **AI agent与垂直模型融合进展**：落地场景超预期或打开估值空间  \n   - **端侧AI业务放量**：ModelHub AIoT解决方案受益于"端侧AI元年"需求'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'data_dict': {'股票代码': ['00700', '00354', '00856', '00696', '行业平均'], '公司名称': ['腾讯控股', '中国软件国际', '伟仕佳杰', '中国民航信息网络', ''], 'PS（倍）': [22.76, 27.89, 12.29, 16.23, 19.54]}, 'df_key_name': '可比公司PS估值'}, 返回结果: DataFrame已保存到writer_data_value中，键名 '可比公司PS估值' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表14。
# 调用工具 add_table, 参数: {'df_key_name': '可比公司PS估值', 'caption': '附：行业可比公司PS估值参考（2024年）'}, 返回结果: 已添加该表格，该表的编号为 表14
# 调用工具 add_plain_text, 参数: {'content': '(注：货币单位统一为港元；数据来源：2024年报行业价值表现数据)'}, 返回结果: 已添加该段文字
# 报告已保存至：company_report.md
#
#
# --------------------开始处理章节 5: 五、公司治理与战略分析 --------------------
#
# 调用工具 add_plain_text, 参数: {'content': '# 五、公司治理与战略分析'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '### (一) 公司治理结构评估\n本章节基于可验证的财务数据、行业比较及市场评级，间接评估4Paradigm（06682.HK）的治理效能。尽管董事会构成与管理层履历等细节未披露，但资本结构与财务表现揭示治理特征。'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'key_indicators_comparison', 'data_dict': {'股票代码': ['06682', '00700', '00020', '行业均值'], '股票简称': ['第四范式', '腾讯控股', '商汤-W', '-'], '总股本（亿股）': [4.66, 93.55, 351.42, 35.21], '资产总计（亿元）': [70.83, 17707.35, 348.27, 1200.65], '负债合计（亿元）': [15.15, 7782.53, 105.35, 560.38], '资产负债率（%）': [21.39, 43.95, 30.25, 46.58], '税后利润（亿元）': [-1.81, 973.84, -26.5, -5.32]}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'key_indicators_comparison' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表15。
# 调用工具 add_table, 参数: {'df_key_name': 'key_indicators_comparison', 'caption': '表15：关键指标对比'}, 返回结果: 已添加该表格，该表的编号为 表15
# 调用工具 add_plain_text, 参数: {'content': '1. **股权结构与资本稳健性**\n截至2024年中报，公司总股本4.66亿股，资产总计70.83亿元，负债合计15.15亿元，资产负债率21.39%，显著低于行业均值46.58%。关键指标对比如下：'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '**分析**：\n- 股权规模较小但负债率优异，反映管理层审慎的财务杠杆策略，降低风险但可能限制扩张。 \n- 税后利润为负（-1.81亿元），与行业亏损中位数（-1.86亿元）一致，凸显盈利压力。'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'annual_report_financial_indicators', 'data_dict': {'股票代码': ['06682', '00700', '00020', '行业均值'], '股票简称': ['第四范式', '腾讯控股', '商汤-W', '-'], '基本每股收益（元）': [-0.61, 22.2, -0.14, -0.85], '每股净资产（元）': [11.52, 111.88, 0.67, 5.43], '净资产收益率（%）': [-5.09, 21.51, -18.1, -12.75], '营业收入（亿元）': [55.77, 6999.38, 39.99, 420.18], '主营利润率（%）': [-5.88, 32.13, -112.94, -15.62]}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'annual_report_financial_indicators' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表16。
# 调用工具 add_table, 参数: {'df_key_name': 'annual_report_financial_indicators', 'caption': '表16：2024年报财务指标'}, 返回结果: 已添加该表格，该表的编号为 表16
#
#
# --------------------开始处理章节 6: 六、投资价值分析与建议 --------------------
#
# 调用工具 add_plain_text, 参数: {'content': '# 六、投资价值分析与建议'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '### 投资建议\n基于对4Paradigm（06682.HK）的财务表现、业务前景及行业定位的综合分析，本报告提出以下投资建议：\n- **投资评级：买入**\n- **目标价：65.0港元**\n  （注：目标价基于主要证券商预测值的中位数，范围55.0–90.84港元；当前股价需参考实时市场数据。）'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'securities_ratings', 'data_dict': {'证券商': ['海通', '交银国际', '大和', '中信证券', '中国国际金融'], '评级': ['优于大市', '买入', '买入', '买入', '优于大市'], '目标价（港元）': [90.84, 64.0, 58.0, 57.0, 55.0], '更新日期': ['2025-06-17', '2025-05-22', '2025-06-19', '2025-05-19', '2025-04-01']}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'securities_ratings' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表17。
# 调用工具 add_table, 参数: {'caption': '表1: 证券商评级及目标价汇总', 'df_key_name': 'securities_ratings'}, 返回结果: 已添加该表格，该表的编号为 表17
# 调用工具 add_plain_text, 参数: {'content': '数据来源：盈利预测概览表。目标价中位数65.0港元反映市场对长期价值的共识。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '2. **核心业务高速增长驱动业绩改善**\n- 收入与毛利稳健提升：2024年总收入达52.61亿元（人民币，下同），同比增长25.1%；毛利润22.45亿元，毛利率42.7%，体现较强定价能力。\n- 亏损持续收窄：2024年归属母公司亏损2.69亿元，同比减亏70.4%；经调整净亏损2.92亿元，减亏29.6%。自2021年起连续4年减亏，为2025–2026年盈利转正奠定基础。\n- 核心平台爆发式增长：先知AI平台收入36.76亿元（占比69.9%），同比增长46.7%。IDC数据显示公司连续六年位居中国机器学习平台市场份额第一，技术壁垒巩固行业领导地位。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '3. **创新产品布局打开增量空间**\n- AI agent与垂直世界模型融合：公司发布“先知AI平台5.0”，整合GPU资源池化、AI agent全流程管理能力，已落地金融、能源、医疗等10余行业，标杆用户数同比增长16%。\n- 端侧AI与一体机解决方案：2025年推出SageOne IA（华为合作）和ModelHub AIoT，支持离线部署与隐私保护。端侧AI市场预计2025年进入爆发期，公司技术适配DeepSeek等开源模型，有望抢占企业级AI落地“最后一公里”。\n- 研发投入保障竞争力：2024年研发费用21.70亿元（费用率41.2%），重点投向生成式AI工具（如AIGS Builder），提升软件开发效率。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '4. **行业对比凸显估值修复潜力**\n在资讯科技业-软件服务-数码解决方案服务板块（共52家）中，公司关键指标优于同业中位水平：\n- 资产负债率33.17%，低于行业中位数42.15%，财务结构稳健。\n- 市净率4.82倍，高于行业中位数1.45倍，反映市场对其技术资产的溢价认可。\n- 收入增速25.1%，显著高于板块中位数（约10%），成长性突出。'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'stock_price_volatility', 'data_dict': {'日期': ['2025-02-28', '2025-04-30', '2025-06-30'], '收盘价(港元)': [43.0, 40.55, 51.4], '月涨跌幅(%)': [-14.17, -10.88, 19.4], '振幅(%)': [42.32, 33.3, 32.64], '换手率(%)': [102.15, 31.8, 42.74]}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'stock_price_volatility' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表18。
# 调用工具 add_table, 参数: {'caption': '表2: 股价波动情况', 'df_key_name': 'stock_price_volatility'}, 返回结果: 已添加该表格，该表的编号为 表18
# 调用工具 add_plain_text, 参数: {'content': '1. **市场风险**\n- 行业竞争加剧：数码解决方案服务行业（港股52家同业）呈现高度分化格局。2024年中报显示，行业超60%企业处于亏损状态（如商汤-W、地平线机器人-W亏损均超26亿元），第四范式虽以21.39%的资产负债率低于行业均值（约50%），但税后利润为-1.81亿港元，主营利润率-8.85%，反映行业整体盈利承压。腾讯控股（00700.HK）等巨头在规模与技术生态上形成壁垒，加剧中小企业生存压力。\n- 股价波动性高：近半年股价呈现剧烈震荡，2025年2月单月振幅达42.32%，6月虽上涨19.4%，但成交量与换手率显著放大（6月换手率42.74%），显示市场情绪敏感度高。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '2. **经营风险**\n- 持续亏损与现金流压力：2024年中报显示公司税后利润为-1.81亿港元，每股收益-0.35港元，每股经营性现金流-0.92港元。尽管技术领先（如自动机器学习算法打破世界纪录），但研发与市场拓展投入导致短期难以盈利。对比行业龙头腾讯控股（主营利润率32.89%），公司盈利模式仍需验证规模化落地能力。\n- 客户集中与项目周期风险：人工智能解决方案依赖大企业客户，项目周期长、定制化程度高，可能导致收入确认延迟。2024年中报营收19.98亿港元，销售成本占比达57.66%（11.52亿港元），反映项目执行成本控制压力。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '3. **政策与合规风险**\n- 数据安全监管趋严：公司业务涉及企业核心数据决策，需符合《网络安全法》《数据安全法》等法规，政策变动可能增加合规成本。\n- 行业补贴政策变动：人工智能行业长期依赖政府补贴与税收优惠，若政策支持力度减弱，将直接影响研发投入与盈利改善进度。'}, 返回结果: 已添加该段文字
# 调用工具 add_plain_text, 参数: {'content': '4. **技术迭代与人才风险**\n- 技术更新速度：据灼识咨询报告，公司虽在自动机器学习领域领先，但AI行业技术迭代迅猛（如生成式AI冲击传统决策模型），需持续投入研发以维持竞争力。\n- 核心人才流失：高端AI人才竞争白热化，同业如商汤-W、创新奇智等均在争夺有限人才资源，人力成本攀升可能加剧亏损。'}, 返回结果: 已添加该段文字
# 调用工具 plain_text_dataframe_to_table, 参数: {'df_key_name': 'risk_summary', 'data_dict': {'风险类别': ['市场风险', '经营风险', '政策风险', '技术风险'], '主要表现': ['行业竞争加剧、股价高波动、同业普遍亏损', '持续亏损（中报净亏1.81亿港元）、现金流紧张（每股现金流-0.92港元）、成本高企', '数据合规成本上升、补贴政策不确定性', '迭代加速、人才争夺激烈'], '潜在影响': ['估值承压，融资难度增加', '短期盈利无改善迹象，依赖外部融资生存', '利润率进一步压缩，技术落地速度放缓', '技术优势被削弱，研发效率下降']}}, 返回结果: DataFrame已保存到writer_data_value中，键名 'risk_summary' 中，稍后可以通过该键名调取插入表格函数add_table给报告中添加表格，该表格的编号为 表19。
# 调用工具 add_table, 参数: {'caption': '表3: 风险提示总结', 'df_key_name': 'risk_summary'}, 返回结果: 已添加该表格，该表的编号为 表19
# 调用工具 add_plain_text, 参数: {'content': '### 结论\n4Paradigm凭借先知AI平台的强劲增长、亏损持续收窄趋势及端侧AI的先发布局，已进入盈利改善通道。结合证券商目标价中位数及行业成长性，给予“买入”评级，目标价65.0港元。但短期盈利困境与行业竞争白热化构成核心风险（券商2025年盈利预测横跨-121.0百万元至86.0百万元），股价高波动反映市场对扭亏时点分歧巨大。投资者需警惕现金流压力及政策合规成本上升对估值的压制，建议关注2025年Q3盈利拐点验证及新品落地进展，以把握估值修复机会。长期竞争力取决于技术商业化进度与成本控制能力。'}, 返回结果: 已添加该段文字
# 报告已保存至：company_report.md
# 报告已保存至：company_report.md

# %% [markdown]
# ## 3.7 转换为docx格式

# %%
## There is a package installer at pandoc’s download page. If you later want to uninstall the package, you can do so by downloading this script and running it with perl uninstall-pandoc.pl.

# Alternatively, you can install pandoc using Homebrew:

#  brew install pandoc

# %%
import pypandoc
import os

def convert_markdown_to_docx(input_file, output_file):
    """
    使用 Pandoc 将 Markdown 文件转换为 DOCX 格式
    自动处理表格、格式和样式
    """
    try:
        # 检查文件是否存在
        if not os.path.exists(input_file):
            raise FileNotFoundError(f"输入文件 {input_file} 不存在")

        # 使用 Pandoc 进行转换
        output = pypandoc.convert_file(
            input_file,
            'docx',
            outputfile=output_file,
            extra_args=[
                '--columns=80',
            ]
        )

    except Exception as e:
        print(f"转换过程中发生错误：{str(e)}")


input_md = "company_report.md"
output_docx = "Company_Research_Report.docx"
    
# 执行转换
convert_markdown_to_docx(input_md, output_docx)
